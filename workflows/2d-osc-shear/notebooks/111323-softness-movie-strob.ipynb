# %%
import numpy as np
import pandas as pd
import polars as pl
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import cm, colors

import glob
import gc
import warnings
import copy
import pathlib
import pickle

import os
import shutil

from scipy import stats
import signac
import freud
import gsd.hoomd
import hoomd
import schmeud
import schmeud._schmeud as schmeud_rs
from schmeud._schmeud import statics
from schmeud import ml
from tqdm import tqdm

from dataclasses import dataclass
from collections import defaultdict

from numba import njit

import seaborn as sns
from matplotlib.collections import PatchCollection
from matplotlib.patches import Circle

# %%
from monk import nb, prep, pair, render, utils, workflow, grid

parent = pathlib.Path(os.getcwd()).parent / "config.yaml"
config = workflow.get_config(parent.as_posix())
parent, config
# Out:
# (PosixPath('/home/ian/Projects/work/monk/workflows/2d-osc-shear/config.yaml'),
#  {'root': '/media/ian/Data2/monk/2d-osc-shear',
#   'origin': '/media/ian/Data2/monk/2d-esl'})

# %%
project: signac.Project = signac.get_project(root=config['root'])
project.doc
# Out:
# {'avail_seed': 18, 'dt': 0.005, 'step_unit': 200, 'equil_time': 100, 'min_periods': 20, 'dumps': 40, 'period_times': [30.0, 100.0, 300.0, 1000.0], 'max_shears': [0.01, 0.02, 0.03, 0.05, 0.08, 0.12], '_status': {}}

# %%
@dataclass(frozen=True, eq=True)
class Statepoint:
    max_shear: float
    period: float
    temp: float
    prep: str

# %%
def plot_data(snap, data, ax=None, lim=None):

    if ax is None:
        fig, ax = plt.subplots()
    else:
        fig = ax.get_figure()

    # extract particle positions and data
    positions = snap.particles.position
    diams = snap.particles.diameter
    color_data = data
    # color_data = np.abs(soft_ffts[:,2:20]).sum(axis=-1)

    # create a list of circles with positions and radius
    circles = [Circle((x[0], x[1]), radius=d/2.0) for x, d in zip(positions, diams)]

    # create a patch collection with circles and color data
    norm = colors.Normalize(-2, 2)
    
    cmap = sns.color_palette("Spectral", as_cmap=True)
    collection = PatchCollection(circles, cmap=cmap, norm=norm)
    collection.set_array(color_data)

    # plot particles with color
    # fig, ax = plt.subplots()
    ax.add_collection(collection)
    ax.autoscale()

    # zoom in 5x
    if lim is None:
        zoom = 4
        xlim = ax.get_xlim()
        ylim = ax.get_ylim()
        ax.set_xlim((xlim[0] + xlim[1])/2 - (xlim[1] - xlim[0])/zoom/2, (xlim[0] + xlim[1])/2 + (xlim[1] - xlim[0])/zoom/2)
        ax.set_ylim((ylim[0] + ylim[1])/2 - (ylim[1] - ylim[0])/zoom/2, (ylim[0] + ylim[1])/2 + (ylim[1] - ylim[0])/zoom/2)
    else:
        ax.set_xlim(-lim, lim)
        ax.set_ylim(-lim, lim)

    # check if has colorbar
    if ax.get_figure().get_axes()[-1] == ax:
        plt.colorbar(collection, label="Softness")

# %%
output = defaultdict(list)

for job in project:
    print(job)
    prep = job.sp["prep"]
    if prep == "ESL":
        continue
    print(prep)
    
    experiments = sorted(glob.glob(job.fn("aqs_therm_experiments/*/*/traj-fire_period-*.gsd")))
    if len(experiments) == 0:
        continue
    for exper in experiments:
        max_shear = utils.extract_between(exper, "max-shear-", "/")
        period = utils.extract_between(exper, "period-", ".gsd")
        temp = utils.extract_between(exper, "temp-", "/")
        df_path = f"aqs_therm_experiments/max-shear-{max_shear}/temp-{temp}/strob-softness_period-{period}.parquet"
        sp = Statepoint(max_shear=float(max_shear), period=float(period), temp=float(temp), prep=prep)
        
        if float(period) != 1000.0 or float(temp) > 5e-3:
            continue

        if job.isfile(df_path):
            dataset = pl.read_parquet(job.fn(df_path), use_pyarrow=True)
        else:
            continue
        
        traj = gsd.hoomd.open(exper)
        
        # softs = np.stack(dataset["soft"].to_numpy())
        # nsofts = softs.reshape(5, 40, 32768)
        # nsofts = nsofts.mean(axis=0)

        # compute fft
        # soft_ffts = np.fft.fft(nsofts.T, axis=-1)

        output_file = f"videos/softness-movie-strob-htl_max-shear-{max_shear}_id-{job.id}.mp4"

        # output[sp].append(soft_ffts)
        fig, ax = plt.subplots()
        frame_path = job.fn("videos/softness-movie-strob/")
        if os.path.exists(frame_path):
            shutil.rmtree(frame_path)
        os.makedirs(job.fn("videos/softness-movie-strob/"), exist_ok=True)
        # i = 0
        for frame, _, soft in tqdm(dataset.rows()):
            # print(frame)
            # if i == 2:
            #     break
            snap = traj[frame]
            name = job.fn("videos/softness-movie-strob/softness-movie-{:04d}.png".format(frame))
            if os.path.exists(name):
                continue

            plot_data(snap, soft, ax=ax, lim=40)
            plt.savefig(name, dpi=150)
            # clear axis
            ax.cla()

        import ffmpeg
        (
        ffmpeg
            .input(job.fn("videos/softness-movie-strob/softness-movie-*.png"), pattern_type="glob", framerate=10)
            .output(output_file).run()
        )
# Out:
# 634e14bc75836df75158fb15f379d8bb
# HTL
# 100%|██████████| 80/80 [04:16<00:00,  3.20s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/634e14bc75836df75158fb15f379d8bb/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5617390defc0] using SAR=1/1
# [libx264 @ 0x5617390defc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5617390defc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x5617390defc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-htl_max-shear-0.01_id-634e14bc75836df75158fb15f379d8bb.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps=0.0 q=-1.0 Lsize=     944kB time=00:00:07.70 bitrate=1004.7kbits/s speed=8.54x
# video:943kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.187110%
# [libx264 @ 0x5617390defc0] frame I:1     Avg QP:15.59  size:143994
# [libx264 @ 0x5617390defc0] frame P:20    Avg QP:17.43  size: 34600
# [libx264 @ 0x5617390defc0] frame B:59    Avg QP:27.16  size:  2179
# [libx264 @ 0x5617390defc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x5617390defc0] mb I  I16..4: 43.4%  0.0% 56.6%
# [libx264 @ 0x5617390defc0] mb P  I16..4:  1.1%  0.0%  1.5%  P16..4: 17.7% 13.3% 15.0%  0.0%  0.0%    skip:51.4%
# [libx264 @ 0x5617390defc0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 15.2%  4.0%  0.9%  direct: 2.2%  skip:77.8%  L0:41.8% L1:35.1% BI:23.1%
# [libx264 @ 0x5617390defc0] coded y,u,v intra: 47.2% 45.5% 44.0% inter: 10.8% 4.6% 3.4%
# [libx264 @ 0x5617390defc0] i16 v,h,dc,p: 87%  8%  5%  0%
# [libx264 @ 0x5617390defc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 28% 16%  6%  8%  6%  8%  5%  9%
# [libx264 @ 0x5617390defc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5617390defc0] ref P L0: 51.1% 13.9% 13.6% 21.5%
# [libx264 @ 0x5617390defc0] ref B L0: 69.4% 28.6%  2.0%
# [libx264 @ 0x5617390defc0] ref B L1: 81.1% 18.9%
# [libx264 @ 0x5617390defc0] kb/s:964.53
# 100%|██████████| 80/80 [04:16<00:00,  3.21s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/634e14bc75836df75158fb15f379d8bb/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55cb583c9fc0] using SAR=1/1
# [libx264 @ 0x55cb583c9fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55cb583c9fc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55cb583c9fc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-htl_max-shear-0.02_id-634e14bc75836df75158fb15f379d8bb.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps=0.0 q=-1.0 Lsize=     969kB time=00:00:07.70 bitrate=1031.4kbits/s speed=11.8x
# video:968kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.182259%
# [libx264 @ 0x55cb583c9fc0] frame I:1     Avg QP:15.72  size:138622
# [libx264 @ 0x55cb583c9fc0] frame P:20    Avg QP:17.72  size: 33168
# [libx264 @ 0x55cb583c9fc0] frame B:59    Avg QP:27.01  size:  3190
# [libx264 @ 0x55cb583c9fc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x55cb583c9fc0] mb I  I16..4: 43.2%  0.0% 56.8%
# [libx264 @ 0x55cb583c9fc0] mb P  I16..4:  1.0%  0.0%  1.6%  P16..4: 19.1% 13.0% 13.6%  0.0%  0.0%    skip:51.7%
# [libx264 @ 0x55cb583c9fc0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 17.6%  5.1%  1.4%  direct: 2.6%  skip:73.1%  L0:43.2% L1:35.4% BI:21.5%
# [libx264 @ 0x55cb583c9fc0] coded y,u,v intra: 48.2% 46.1% 45.3% inter: 12.2% 4.9% 4.1%
# [libx264 @ 0x55cb583c9fc0] i16 v,h,dc,p: 88%  7%  5%  0%
# [libx264 @ 0x55cb583c9fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 27% 16%  6%  8%  7%  9%  6%  9%
# [libx264 @ 0x55cb583c9fc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55cb583c9fc0] ref P L0: 46.8% 14.3% 11.6% 27.2%
# [libx264 @ 0x55cb583c9fc0] ref B L0: 66.7% 30.2%  3.1%
# [libx264 @ 0x55cb583c9fc0] ref B L1: 77.1% 22.9%
# [libx264 @ 0x55cb583c9fc0] kb/s:990.22
# 100%|██████████| 80/80 [04:19<00:00,  3.25s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/634e14bc75836df75158fb15f379d8bb/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5572c7ec5fc0] using SAR=1/1
# [libx264 @ 0x5572c7ec5fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5572c7ec5fc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x5572c7ec5fc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-htl_max-shear-0.03_id-634e14bc75836df75158fb15f379d8bb.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps= 56 q=-1.0 Lsize=    1177kB time=00:00:07.70 bitrate=1252.7kbits/s speed=5.39x
# video:1176kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.151337%
# [libx264 @ 0x5572c7ec5fc0] frame I:1     Avg QP:17.11  size:102660
# [libx264 @ 0x5572c7ec5fc0] frame P:20    Avg QP:18.09  size: 39616
# [libx264 @ 0x5572c7ec5fc0] frame B:59    Avg QP:26.50  size:  5225
# [libx264 @ 0x5572c7ec5fc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x5572c7ec5fc0] mb I  I16..4: 43.3%  0.0% 56.7%
# [libx264 @ 0x5572c7ec5fc0] mb P  I16..4:  1.0%  0.0%  4.0%  P16..4: 18.1% 12.3% 12.8%  0.0%  0.0%    skip:51.7%
# [libx264 @ 0x5572c7ec5fc0] mb B  I16..4:  0.0%  0.0%  0.2%  B16..8: 18.1%  6.2%  2.3%  direct: 3.3%  skip:69.9%  L0:42.4% L1:35.2% BI:22.4%
# [libx264 @ 0x5572c7ec5fc0] coded y,u,v intra: 62.5% 61.3% 59.5% inter: 14.6% 6.1% 6.2%
# [libx264 @ 0x5572c7ec5fc0] i16 v,h,dc,p: 88%  6%  5%  0%
# [libx264 @ 0x5572c7ec5fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 23% 16%  6%  9%  7% 10%  6% 10%
# [libx264 @ 0x5572c7ec5fc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5572c7ec5fc0] ref P L0: 38.8% 15.2% 16.3% 29.7%
# [libx264 @ 0x5572c7ec5fc0] ref B L0: 69.2% 25.8%  4.9%
# [libx264 @ 0x5572c7ec5fc0] ref B L1: 82.2% 17.8%
# [libx264 @ 0x5572c7ec5fc0] kb/s:1203.26
# 100%|██████████| 80/80 [04:18<00:00,  3.23s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/634e14bc75836df75158fb15f379d8bb/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55f09add0fc0] using SAR=1/1
# [libx264 @ 0x55f09add0fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55f09add0fc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55f09add0fc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-htl_max-shear-0.05_id-634e14bc75836df75158fb15f379d8bb.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps= 79 q=-1.0 Lsize=    2273kB time=00:00:07.70 bitrate=2417.8kbits/s speed=7.59x
# video:2271kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.079044%
# [libx264 @ 0x55f09add0fc0] frame I:1     Avg QP:17.71  size: 88967
# [libx264 @ 0x55f09add0fc0] frame P:20    Avg QP:19.18  size: 53914
# [libx264 @ 0x55f09add0fc0] frame B:59    Avg QP:26.64  size: 19617
# [libx264 @ 0x55f09add0fc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x55f09add0fc0] mb I  I16..4: 43.3%  0.0% 56.7%
# [libx264 @ 0x55f09add0fc0] mb P  I16..4:  1.0%  0.0% 11.1%  P16..4: 10.7% 12.3% 13.5%  0.0%  0.0%    skip:51.3%
# [libx264 @ 0x55f09add0fc0] mb B  I16..4:  0.0%  0.0%  2.4%  B16..8: 16.5% 11.2%  6.3%  direct: 5.3%  skip:58.3%  L0:39.4% L1:37.1% BI:23.6%
# [libx264 @ 0x55f09add0fc0] coded y,u,v intra: 83.2% 82.9% 80.2% inter: 28.0% 13.8% 16.9%
# [libx264 @ 0x55f09add0fc0] i16 v,h,dc,p: 86%  7%  6%  0%
# [libx264 @ 0x55f09add0fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 18% 17%  7% 10%  8% 11%  7% 11%
# [libx264 @ 0x55f09add0fc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55f09add0fc0] ref P L0: 35.1% 20.5% 23.7% 20.8%
# [libx264 @ 0x55f09add0fc0] ref B L0: 75.5% 18.2%  6.3%
# [libx264 @ 0x55f09add0fc0] ref B L1: 88.0% 12.0%
# [libx264 @ 0x55f09add0fc0] kb/s:2324.62
# 100%|██████████| 80/80 [04:20<00:00,  3.26s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/634e14bc75836df75158fb15f379d8bb/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x558fb8cf1fc0] using SAR=1/1
# [libx264 @ 0x558fb8cf1fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x558fb8cf1fc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x558fb8cf1fc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-htl_max-shear-0.08_id-634e14bc75836df75158fb15f379d8bb.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps= 49 q=-1.0 Lsize=    4276kB time=00:00:07.70 bitrate=4549.5kbits/s speed=4.69x
# video:4274kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.042723%
# [libx264 @ 0x558fb8cf1fc0] frame I:1     Avg QP:17.89  size: 86076
# [libx264 @ 0x558fb8cf1fc0] frame P:20    Avg QP:20.47  size: 70924
# [libx264 @ 0x558fb8cf1fc0] frame B:59    Avg QP:26.54  size: 48674
# [libx264 @ 0x558fb8cf1fc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x558fb8cf1fc0] mb I  I16..4: 43.3%  0.0% 56.7%
# [libx264 @ 0x558fb8cf1fc0] mb P  I16..4:  0.9%  0.0% 27.1%  P16..4:  3.3%  6.2% 11.0%  0.0%  0.0%    skip:51.5%
# [libx264 @ 0x558fb8cf1fc0] mb B  I16..4:  0.0%  0.0% 12.9%  B16..8:  8.9% 11.8% 10.2%  direct: 3.4%  skip:52.8%  L0:40.0% L1:32.1% BI:27.9%
# [libx264 @ 0x558fb8cf1fc0] coded y,u,v intra: 93.7% 93.9% 90.3% inter: 32.9% 22.5% 25.5%
# [libx264 @ 0x558fb8cf1fc0] i16 v,h,dc,p: 86%  6%  7%  2%
# [libx264 @ 0x558fb8cf1fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11% 17% 17%  8% 10%  8% 11%  7% 11%
# [libx264 @ 0x558fb8cf1fc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x558fb8cf1fc0] ref P L0: 29.1% 21.3% 27.5% 22.2%
# [libx264 @ 0x558fb8cf1fc0] ref B L0: 74.7% 18.9%  6.4%
# [libx264 @ 0x558fb8cf1fc0] ref B L1: 88.7% 11.3%
# [libx264 @ 0x558fb8cf1fc0] kb/s:4376.36
# 100%|██████████| 80/80 [04:24<00:00,  3.30s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/634e14bc75836df75158fb15f379d8bb/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55da91f15fc0] using SAR=1/1
# [libx264 @ 0x55da91f15fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55da91f15fc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55da91f15fc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-htl_max-shear-0.12_id-634e14bc75836df75158fb15f379d8bb.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps= 45 q=-1.0 Lsize=    5371kB time=00:00:07.70 bitrate=5713.6kbits/s speed=4.37x
# video:5369kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.033651%
# [libx264 @ 0x55da91f15fc0] frame I:1     Avg QP:17.99  size: 87126
# [libx264 @ 0x55da91f15fc0] frame P:20    Avg QP:20.75  size: 76315
# [libx264 @ 0x55da91f15fc0] frame B:59    Avg QP:26.69  size: 65822
# [libx264 @ 0x55da91f15fc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x55da91f15fc0] mb I  I16..4: 43.1%  0.0% 56.9%
# [libx264 @ 0x55da91f15fc0] mb P  I16..4:  0.9%  0.0% 36.3%  P16..4:  1.4%  3.0%  6.9%  0.0%  0.0%    skip:51.5%
# [libx264 @ 0x55da91f15fc0] mb B  I16..4:  0.1%  0.0% 26.4%  B16..8:  3.7%  7.5%  8.7%  direct: 1.1%  skip:52.6%  L0:39.2% L1:30.9% BI:29.9%
# [libx264 @ 0x55da91f15fc0] coded y,u,v intra: 95.7% 96.0% 92.4% inter: 23.6% 19.9% 19.9%
# [libx264 @ 0x55da91f15fc0] i16 v,h,dc,p: 85%  6%  8%  1%
# [libx264 @ 0x55da91f15fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11% 17% 16%  8% 10%  8% 11%  7% 11%
# [libx264 @ 0x55da91f15fc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55da91f15fc0] ref P L0: 25.8% 17.1% 30.5% 26.6%
# [libx264 @ 0x55da91f15fc0] ref B L0: 70.9% 21.9%  7.2%
# [libx264 @ 0x55da91f15fc0] ref B L1: 86.3% 13.7%
# [libx264 @ 0x55da91f15fc0] kb/s:5496.93
# 7ec2f6aca035e69077eab24383a21cb6
# cfa1e4c0007fd65d020f809715a6f0b4
# HTL
# 100%|██████████| 80/80 [04:22<00:00,  3.28s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/cfa1e4c0007fd65d020f809715a6f0b4/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55d0b0124fc0] using SAR=1/1
# [libx264 @ 0x55d0b0124fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55d0b0124fc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55d0b0124fc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-htl_max-shear-0.01_id-cfa1e4c0007fd65d020f809715a6f0b4.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps=0.0 q=-1.0 Lsize=     967kB time=00:00:07.70 bitrate=1028.7kbits/s speed=10.8x
# video:965kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.183552%
# [libx264 @ 0x55d0b0124fc0] frame I:1     Avg QP:15.15  size:156058
# [libx264 @ 0x55d0b0124fc0] frame P:21    Avg QP:17.75  size: 33409
# [libx264 @ 0x55d0b0124fc0] frame B:58    Avg QP:27.19  size:  2241
# [libx264 @ 0x55d0b0124fc0] consecutive B-frames:  2.5%  2.5%  0.0% 95.0%
# [libx264 @ 0x55d0b0124fc0] mb I  I16..4: 43.3%  0.0% 56.7%
# [libx264 @ 0x55d0b0124fc0] mb P  I16..4:  1.0%  0.0%  1.3%  P16..4: 17.6% 13.0% 15.3%  0.0%  0.0%    skip:51.9%
# [libx264 @ 0x55d0b0124fc0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 14.4%  3.8%  1.0%  direct: 2.6%  skip:78.1%  L0:41.2% L1:34.0% BI:24.8%
# [libx264 @ 0x55d0b0124fc0] coded y,u,v intra: 45.5% 43.4% 43.5% inter: 11.2% 4.7% 3.5%
# [libx264 @ 0x55d0b0124fc0] i16 v,h,dc,p: 87%  8%  6%  0%
# [libx264 @ 0x55d0b0124fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 29% 17%  5%  7%  6%  9%  6%  9%
# [libx264 @ 0x55d0b0124fc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55d0b0124fc0] ref P L0: 48.6% 13.9% 17.1% 20.5%
# [libx264 @ 0x55d0b0124fc0] ref B L0: 72.9% 27.0%  0.2%
# [libx264 @ 0x55d0b0124fc0] ref B L1: 81.2% 18.8%
# [libx264 @ 0x55d0b0124fc0] kb/s:987.60
# 100%|██████████| 80/80 [04:22<00:00,  3.28s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/cfa1e4c0007fd65d020f809715a6f0b4/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55b2332a5fc0] using SAR=1/1
# [libx264 @ 0x55b2332a5fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55b2332a5fc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55b2332a5fc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-htl_max-shear-0.02_id-cfa1e4c0007fd65d020f809715a6f0b4.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps=0.0 q=-1.0 Lsize=    1034kB time=00:00:07.70 bitrate=1100.2kbits/s speed=10.9x
# video:1032kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.172359%
# [libx264 @ 0x55b2332a5fc0] frame I:1     Avg QP:16.56  size:117746
# [libx264 @ 0x55b2332a5fc0] frame P:20    Avg QP:17.68  size: 37940
# [libx264 @ 0x55b2332a5fc0] frame B:59    Avg QP:26.92  size:  3049
# [libx264 @ 0x55b2332a5fc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x55b2332a5fc0] mb I  I16..4: 43.3%  0.0% 56.7%
# [libx264 @ 0x55b2332a5fc0] mb P  I16..4:  1.0%  0.0%  2.6%  P16..4: 18.2% 12.4% 14.2%  0.0%  0.0%    skip:51.6%
# [libx264 @ 0x55b2332a5fc0] mb B  I16..4:  0.0%  0.0%  0.1%  B16..8: 16.7%  4.6%  1.3%  direct: 2.5%  skip:74.8%  L0:39.9% L1:37.4% BI:22.7%
# [libx264 @ 0x55b2332a5fc0] coded y,u,v intra: 54.2% 52.8% 51.4% inter: 11.8% 5.0% 4.4%
# [libx264 @ 0x55b2332a5fc0] i16 v,h,dc,p: 87%  8%  5%  0%
# [libx264 @ 0x55b2332a5fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 26% 16%  6%  8%  7%  9%  6% 10%
# [libx264 @ 0x55b2332a5fc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55b2332a5fc0] ref P L0: 48.8% 16.4% 13.5% 21.3%
# [libx264 @ 0x55b2332a5fc0] ref B L0: 70.8% 26.8%  2.4%
# [libx264 @ 0x55b2332a5fc0] ref B L1: 81.4% 18.6%
# [libx264 @ 0x55b2332a5fc0] kb/s:1056.42
# 100%|██████████| 80/80 [04:25<00:00,  3.32s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/cfa1e4c0007fd65d020f809715a6f0b4/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x563bac716fc0] using SAR=1/1
# [libx264 @ 0x563bac716fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x563bac716fc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x563bac716fc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-htl_max-shear-0.03_id-cfa1e4c0007fd65d020f809715a6f0b4.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps=0.0 q=-1.0 Lsize=    1201kB time=00:00:07.70 bitrate=1277.2kbits/s speed=10.8x
# video:1199kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.148427%
# [libx264 @ 0x563bac716fc0] frame I:1     Avg QP:16.93  size:108029
# [libx264 @ 0x563bac716fc0] frame P:20    Avg QP:18.25  size: 40176
# [libx264 @ 0x563bac716fc0] frame B:59    Avg QP:26.23  size:  5344
# [libx264 @ 0x563bac716fc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x563bac716fc0] mb I  I16..4: 43.3%  0.0% 56.7%
# [libx264 @ 0x563bac716fc0] mb P  I16..4:  1.0%  0.0%  3.9%  P16..4: 17.0% 12.5% 13.4%  0.0%  0.0%    skip:52.1%
# [libx264 @ 0x563bac716fc0] mb B  I16..4:  0.0%  0.0%  0.2%  B16..8: 18.8%  6.5%  2.3%  direct: 3.6%  skip:68.7%  L0:41.1% L1:37.4% BI:21.5%
# [libx264 @ 0x563bac716fc0] coded y,u,v intra: 61.7% 60.0% 58.9% inter: 15.2% 6.1% 6.4%
# [libx264 @ 0x563bac716fc0] i16 v,h,dc,p: 87%  8%  5%  0%
# [libx264 @ 0x563bac716fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 23% 16%  7%  9%  7% 10%  6% 10%
# [libx264 @ 0x563bac716fc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x563bac716fc0] ref P L0: 43.6% 17.7% 17.3% 21.5%
# [libx264 @ 0x563bac716fc0] ref B L0: 71.6% 22.0%  6.3%
# [libx264 @ 0x563bac716fc0] ref B L1: 81.9% 18.1%
# [libx264 @ 0x563bac716fc0] kb/s:1226.86
# 100%|██████████| 80/80 [04:25<00:00,  3.32s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/cfa1e4c0007fd65d020f809715a6f0b4/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5570762abfc0] using SAR=1/1
# [libx264 @ 0x5570762abfc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5570762abfc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x5570762abfc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-htl_max-shear-0.05_id-cfa1e4c0007fd65d020f809715a6f0b4.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps= 77 q=-1.0 Lsize=    2637kB time=00:00:07.70 bitrate=2805.3kbits/s speed=7.41x
# video:2635kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.068117%
# [libx264 @ 0x5570762abfc0] frame I:1     Avg QP:17.73  size: 89705
# [libx264 @ 0x5570762abfc0] frame P:20    Avg QP:19.55  size: 58832
# [libx264 @ 0x5570762abfc0] frame B:59    Avg QP:26.31  size: 24259
# [libx264 @ 0x5570762abfc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x5570762abfc0] mb I  I16..4: 43.3%  0.0% 56.7%
# [libx264 @ 0x5570762abfc0] mb P  I16..4:  1.0%  0.0% 14.5%  P16..4:  8.4% 11.2% 13.5%  0.0%  0.0%    skip:51.3%
# [libx264 @ 0x5570762abfc0] mb B  I16..4:  0.0%  0.0%  3.1%  B16..8: 15.4% 12.4%  7.5%  direct: 5.8%  skip:55.8%  L0:38.6% L1:36.8% BI:24.7%
# [libx264 @ 0x5570762abfc0] coded y,u,v intra: 85.9% 85.7% 82.7% inter: 31.1% 16.4% 19.7%
# [libx264 @ 0x5570762abfc0] i16 v,h,dc,p: 87%  7%  6%  0%
# [libx264 @ 0x5570762abfc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11% 18% 17%  8% 10%  8% 11%  7% 11%
# [libx264 @ 0x5570762abfc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5570762abfc0] ref P L0: 33.5% 20.9% 25.2% 20.5%
# [libx264 @ 0x5570762abfc0] ref B L0: 75.7% 17.9%  6.4%
# [libx264 @ 0x5570762abfc0] ref B L1: 88.8% 11.2%
# [libx264 @ 0x5570762abfc0] kb/s:2697.61
# 100%|██████████| 80/80 [04:27<00:00,  3.34s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/cfa1e4c0007fd65d020f809715a6f0b4/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55d924b73fc0] using SAR=1/1
# [libx264 @ 0x55d924b73fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55d924b73fc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55d924b73fc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-htl_max-shear-0.08_id-cfa1e4c0007fd65d020f809715a6f0b4.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps= 63 q=-1.0 Lsize=    4577kB time=00:00:07.70 bitrate=4869.1kbits/s speed=6.11x
# video:4575kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.039661%
# [libx264 @ 0x55d924b73fc0] frame I:1     Avg QP:17.92  size: 87164
# [libx264 @ 0x55d924b73fc0] frame P:20    Avg QP:20.44  size: 71734
# [libx264 @ 0x55d924b73fc0] frame B:59    Avg QP:26.58  size: 53597
# [libx264 @ 0x55d924b73fc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x55d924b73fc0] mb I  I16..4: 43.7%  0.0% 56.3%
# [libx264 @ 0x55d924b73fc0] mb P  I16..4:  1.1%  0.0% 30.8%  P16..4:  2.4%  5.3%  9.2%  0.0%  0.0%    skip:51.3%
# [libx264 @ 0x55d924b73fc0] mb B  I16..4:  0.1%  0.0% 16.9%  B16..8:  7.2% 10.8%  9.6%  direct: 2.7%  skip:52.7%  L0:40.5% L1:31.2% BI:28.3%
# [libx264 @ 0x55d924b73fc0] coded y,u,v intra: 94.3% 94.6% 90.9% inter: 30.4% 22.4% 24.3%
# [libx264 @ 0x55d924b73fc0] i16 v,h,dc,p: 84%  6%  8%  1%
# [libx264 @ 0x55d924b73fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11% 17% 17%  8% 10%  8% 11%  7% 11%
# [libx264 @ 0x55d924b73fc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55d924b73fc0] ref P L0: 28.9% 20.4% 28.5% 22.2%
# [libx264 @ 0x55d924b73fc0] ref B L0: 74.3% 19.5%  6.2%
# [libx264 @ 0x55d924b73fc0] ref B L1: 88.2% 11.8%
# [libx264 @ 0x55d924b73fc0] kb/s:4684.07
# 100%|██████████| 80/80 [04:27<00:00,  3.35s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
# ...
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55aecf7fdfc0] using SAR=1/1
# [libx264 @ 0x55aecf7fdfc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55aecf7fdfc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55aecf7fdfc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-htl_max-shear-0.03_id-9158e73b2e4c9fd1a565e1e5d1bc3af5.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps=0.0 q=-1.0 Lsize=    1200kB time=00:00:07.70 bitrate=1276.9kbits/s speed=12.3x
# video:1198kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.148472%
# [libx264 @ 0x55aecf7fdfc0] frame I:1     Avg QP:17.35  size:100193
# [libx264 @ 0x55aecf7fdfc0] frame P:20    Avg QP:18.06  size: 40600
# [libx264 @ 0x55aecf7fdfc0] frame B:59    Avg QP:26.71  size:  5327
# [libx264 @ 0x55aecf7fdfc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x55aecf7fdfc0] mb I  I16..4: 43.3%  0.0% 56.7%
# [libx264 @ 0x55aecf7fdfc0] mb P  I16..4:  1.1%  0.0%  4.2%  P16..4: 17.2% 12.6% 12.9%  0.0%  0.0%    skip:52.0%
# [libx264 @ 0x55aecf7fdfc0] mb B  I16..4:  0.0%  0.0%  0.2%  B16..8: 17.8%  5.9%  2.1%  direct: 3.4%  skip:70.6%  L0:41.3% L1:36.9% BI:21.8%
# [libx264 @ 0x55aecf7fdfc0] coded y,u,v intra: 63.2% 61.6% 60.9% inter: 14.4% 5.9% 5.9%
# [libx264 @ 0x55aecf7fdfc0] i16 v,h,dc,p: 86%  9%  5%  0%
# [libx264 @ 0x55aecf7fdfc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 23% 16%  6%  9%  7% 10%  6% 10%
# [libx264 @ 0x55aecf7fdfc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55aecf7fdfc0] ref P L0: 42.9% 16.8% 16.2% 24.0%
# [libx264 @ 0x55aecf7fdfc0] ref B L0: 71.6% 24.3%  4.1%
# [libx264 @ 0x55aecf7fdfc0] ref B L1: 81.1% 18.9%
# [libx264 @ 0x55aecf7fdfc0] kb/s:1226.49
# 100%|██████████| 80/80 [04:31<00:00,  3.40s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/9158e73b2e4c9fd1a565e1e5d1bc3af5/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x556375cb5fc0] using SAR=1/1
# [libx264 @ 0x556375cb5fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x556375cb5fc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x556375cb5fc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-htl_max-shear-0.05_id-9158e73b2e4c9fd1a565e1e5d1bc3af5.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps=0.0 q=-1.0 Lsize=    2752kB time=00:00:07.70 bitrate=2927.5kbits/s speed=8.25x
# video:2750kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.065271%
# [libx264 @ 0x556375cb5fc0] frame I:1     Avg QP:17.73  size: 89680
# [libx264 @ 0x556375cb5fc0] frame P:20    Avg QP:19.55  size: 59877
# [libx264 @ 0x556375cb5fc0] frame B:59    Avg QP:26.64  size: 25900
# [libx264 @ 0x556375cb5fc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x556375cb5fc0] mb I  I16..4: 43.3%  0.0% 56.7%
# [libx264 @ 0x556375cb5fc0] mb P  I16..4:  1.1%  0.0% 15.7%  P16..4:  8.0% 10.8% 13.2%  0.0%  0.0%    skip:51.3%
# [libx264 @ 0x556375cb5fc0] mb B  I16..4:  0.0%  0.0%  3.7%  B16..8: 15.0% 12.5%  7.7%  direct: 5.6%  skip:55.6%  L0:40.0% L1:34.7% BI:25.3%
# [libx264 @ 0x556375cb5fc0] coded y,u,v intra: 87.2% 87.0% 83.8% inter: 31.5% 17.0% 20.5%
# [libx264 @ 0x556375cb5fc0] i16 v,h,dc,p: 88%  7%  5%  0%
# [libx264 @ 0x556375cb5fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 18% 17%  7% 10%  8% 11%  7% 11%
# [libx264 @ 0x556375cb5fc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x556375cb5fc0] ref P L0: 33.9% 20.7% 25.1% 20.3%
# [libx264 @ 0x556375cb5fc0] ref B L0: 76.8% 17.3%  5.8%
# [libx264 @ 0x556375cb5fc0] ref B L1: 88.8% 11.2%
# [libx264 @ 0x556375cb5fc0] kb/s:2815.29
# 100%|██████████| 80/80 [04:30<00:00,  3.38s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/9158e73b2e4c9fd1a565e1e5d1bc3af5/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55bf3535cfc0] using SAR=1/1
# [libx264 @ 0x55bf3535cfc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55bf3535cfc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55bf3535cfc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-htl_max-shear-0.08_id-9158e73b2e4c9fd1a565e1e5d1bc3af5.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps= 73 q=-1.0 Lsize=    4608kB time=00:00:07.70 bitrate=4902.9kbits/s speed=   7x
# video:4607kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.039388%
# [libx264 @ 0x55bf3535cfc0] frame I:1     Avg QP:17.93  size: 86381
# [libx264 @ 0x55bf3535cfc0] frame P:20    Avg QP:20.59  size: 71529
# [libx264 @ 0x55bf3535cfc0] frame B:59    Avg QP:26.44  size: 54230
# [libx264 @ 0x55bf3535cfc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x55bf3535cfc0] mb I  I16..4: 43.3%  0.0% 56.7%
# [libx264 @ 0x55bf3535cfc0] mb P  I16..4:  1.0%  0.0% 31.5%  P16..4:  2.4%  4.7%  8.9%  0.0%  0.0%    skip:51.4%
# [libx264 @ 0x55bf3535cfc0] mb B  I16..4:  0.1%  0.0% 17.6%  B16..8:  7.1% 10.4%  9.5%  direct: 2.6%  skip:52.7%  L0:38.2% L1:33.0% BI:28.8%
# [libx264 @ 0x55bf3535cfc0] coded y,u,v intra: 94.5% 94.8% 90.8% inter: 30.0% 22.4% 24.0%
# [libx264 @ 0x55bf3535cfc0] i16 v,h,dc,p: 84%  7%  7%  2%
# [libx264 @ 0x55bf3535cfc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11% 17% 17%  8% 10%  8% 11%  7% 11%
# [libx264 @ 0x55bf3535cfc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55bf3535cfc0] ref P L0: 27.1% 20.5% 29.6% 22.9%
# [libx264 @ 0x55bf3535cfc0] ref B L0: 73.7% 20.0%  6.3%
# [libx264 @ 0x55bf3535cfc0] ref B L1: 87.8% 12.2%
# [libx264 @ 0x55bf3535cfc0] kb/s:4716.53
# 100%|██████████| 80/80 [04:31<00:00,  3.39s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/9158e73b2e4c9fd1a565e1e5d1bc3af5/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x563f6baa6fc0] using SAR=1/1
# [libx264 @ 0x563f6baa6fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x563f6baa6fc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x563f6baa6fc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-htl_max-shear-0.12_id-9158e73b2e4c9fd1a565e1e5d1bc3af5.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps= 71 q=-1.0 Lsize=    5351kB time=00:00:07.70 bitrate=5692.5kbits/s speed=6.88x
# video:5349kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.033776%
# [libx264 @ 0x563f6baa6fc0] frame I:1     Avg QP:17.95  size: 84984
# [libx264 @ 0x563f6baa6fc0] frame P:20    Avg QP:20.65  size: 74789
# [libx264 @ 0x563f6baa6fc0] frame B:59    Avg QP:26.32  size: 66030
# [libx264 @ 0x563f6baa6fc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x563f6baa6fc0] mb I  I16..4: 43.3%  0.0% 56.7%
# [libx264 @ 0x563f6baa6fc0] mb P  I16..4:  1.0%  0.0% 37.3%  P16..4:  1.3%  2.6%  6.4%  0.0%  0.0%    skip:51.5%
# [libx264 @ 0x563f6baa6fc0] mb B  I16..4:  0.1%  0.0% 28.6%  B16..8:  3.2%  6.7%  7.7%  direct: 1.0%  skip:52.7%  L0:40.0% L1:31.4% BI:28.6%
# [libx264 @ 0x563f6baa6fc0] coded y,u,v intra: 95.7% 96.1% 92.2% inter: 21.5% 18.8% 18.3%
# [libx264 @ 0x563f6baa6fc0] i16 v,h,dc,p: 86%  6%  8%  1%
# [libx264 @ 0x563f6baa6fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 17% 16%  8% 10%  8% 11%  7% 11%
# [libx264 @ 0x563f6baa6fc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x563f6baa6fc0] ref P L0: 26.1% 16.9% 30.2% 26.8%
# [libx264 @ 0x563f6baa6fc0] ref B L0: 69.7% 22.4%  7.9%
# [libx264 @ 0x563f6baa6fc0] ref B L1: 85.7% 14.3%
# [libx264 @ 0x563f6baa6fc0] kb/s:5476.53
# c6d7afd0de62bfa16d05da47815227eb
# bf92a185d043ce3ef666e05e427c7e76
# a8f2c249ed85533b56b0729b7ab96d18

# %%
output = defaultdict(list)

for job in project:
    print(job)
    prep = job.sp["prep"]
    if prep != "ESL":
        continue
    print(prep)
    
    experiments = sorted(glob.glob(job.fn("aqs_therm_experiments/*/*/traj-fire_period-*.gsd")))
    if len(experiments) == 0:
        continue
    for exper in experiments:
        max_shear = utils.extract_between(exper, "max-shear-", "/")
        period = utils.extract_between(exper, "period-", ".gsd")
        temp = utils.extract_between(exper, "temp-", "/")
        df_path = f"aqs_therm_experiments/max-shear-{max_shear}/temp-{temp}/strob-softness_period-{period}.parquet"
        sp = Statepoint(max_shear=float(max_shear), period=float(period), temp=float(temp), prep=prep)
        
        if float(period) != 1000.0 or float(temp) > 5e-3:
            continue

        if job.isfile(df_path):
            dataset = pl.read_parquet(job.fn(df_path), use_pyarrow=True)
        else:
            continue
        
        traj = gsd.hoomd.open(exper)
        
        # softs = np.stack(dataset["soft"].to_numpy())
        # nsofts = softs.reshape(5, 40, 32768)
        # nsofts = nsofts.mean(axis=0)

        # compute fft
        # soft_ffts = np.fft.fft(nsofts.T, axis=-1)

        output_file = f"videos/softness-movie-strob-esl_max-shear-{max_shear}_id-{job.id}.mp4"

        # output[sp].append(soft_ffts)
        fig, ax = plt.subplots()
        frame_path = job.fn("videos/softness-movie-strob/")
        if os.path.exists(frame_path):
            shutil.rmtree(frame_path)
        os.makedirs(job.fn("videos/softness-movie-strob/"), exist_ok=True)
        # i = 0
        for frame, _, soft in tqdm(dataset.rows()):
            # print(frame)
            # if i == 2:
            #     break
            snap = traj[frame]
            name = job.fn("videos/softness-movie-strob/softness-movie-{:04d}.png".format(frame))
            if os.path.exists(name):
                continue

            plot_data(snap, soft, ax=ax, lim=40)
            plt.savefig(name, dpi=150)
            # clear axis
            ax.cla()

        import ffmpeg
        (
        ffmpeg
            .input(job.fn("videos/softness-movie-strob/softness-movie-*.png"), pattern_type="glob", framerate=10)
            .output(output_file).run()
        )
# Out:
# 634e14bc75836df75158fb15f379d8bb
# 7ec2f6aca035e69077eab24383a21cb6
# ESL
# 100%|██████████| 80/80 [04:21<00:00,  3.27s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/7ec2f6aca035e69077eab24383a21cb6/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55d42eda3fc0] using SAR=1/1
# [libx264 @ 0x55d42eda3fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55d42eda3fc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55d42eda3fc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-esl_max-shear-0.01_id-7ec2f6aca035e69077eab24383a21cb6.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps=0.0 q=-1.0 Lsize=     859kB time=00:00:07.70 bitrate= 914.1kbits/s speed=12.7x
# video:857kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.205694%
# [libx264 @ 0x55d42eda3fc0] frame I:1     Avg QP:14.53  size:166346
# [libx264 @ 0x55d42eda3fc0] frame P:20    Avg QP:17.53  size: 30291
# [libx264 @ 0x55d42eda3fc0] frame B:59    Avg QP:26.69  size:  1782
# [libx264 @ 0x55d42eda3fc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x55d42eda3fc0] mb I  I16..4: 43.6%  0.0% 56.4%
# [libx264 @ 0x55d42eda3fc0] mb P  I16..4:  1.0%  0.0%  1.1%  P16..4: 17.5% 13.3% 15.3%  0.0%  0.0%    skip:51.8%
# [libx264 @ 0x55d42eda3fc0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 15.4%  3.8%  0.8%  direct: 1.7%  skip:78.3%  L0:43.6% L1:35.9% BI:20.5%
# [libx264 @ 0x55d42eda3fc0] coded y,u,v intra: 43.5% 40.9% 40.9% inter: 9.7% 5.0% 3.2%
# [libx264 @ 0x55d42eda3fc0] i16 v,h,dc,p: 87%  7%  6%  0%
# [libx264 @ 0x55d42eda3fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 29% 17%  5%  7%  6%  8%  5%  9%
# [libx264 @ 0x55d42eda3fc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55d42eda3fc0] ref P L0: 48.8% 14.7% 17.3% 19.2%
# [libx264 @ 0x55d42eda3fc0] ref B L0: 70.1% 27.7%  2.2%
# [libx264 @ 0x55d42eda3fc0] ref B L1: 83.4% 16.6%
# [libx264 @ 0x55d42eda3fc0] kb/s:877.33
# 100%|██████████| 80/80 [04:20<00:00,  3.26s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/7ec2f6aca035e69077eab24383a21cb6/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55a5504ddfc0] using SAR=1/1
# [libx264 @ 0x55a5504ddfc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55a5504ddfc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55a5504ddfc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-esl_max-shear-0.02_id-7ec2f6aca035e69077eab24383a21cb6.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps=0.0 q=-1.0 Lsize=     846kB time=00:00:07.70 bitrate= 900.4kbits/s speed=13.9x
# video:845kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.208834%
# [libx264 @ 0x55a5504ddfc0] frame I:1     Avg QP:14.59  size:164319
# [libx264 @ 0x55a5504ddfc0] frame P:20    Avg QP:17.61  size: 29786
# [libx264 @ 0x55a5504ddfc0] frame B:59    Avg QP:26.85  size:  1764
# [libx264 @ 0x55a5504ddfc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x55a5504ddfc0] mb I  I16..4: 43.2%  0.0% 56.8%
# [libx264 @ 0x55a5504ddfc0] mb P  I16..4:  1.0%  0.0%  1.0%  P16..4: 18.3% 13.2% 14.9%  0.0%  0.0%    skip:51.5%
# [libx264 @ 0x55a5504ddfc0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 15.7%  3.7%  0.8%  direct: 1.7%  skip:78.1%  L0:44.2% L1:35.4% BI:20.3%
# [libx264 @ 0x55a5504ddfc0] coded y,u,v intra: 43.6% 41.1% 41.0% inter: 9.7% 4.9% 3.2%
# [libx264 @ 0x55a5504ddfc0] i16 v,h,dc,p: 86% 10%  5%  0%
# [libx264 @ 0x55a5504ddfc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 29% 17%  6%  8%  6%  8%  5%  9%
# [libx264 @ 0x55a5504ddfc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55a5504ddfc0] ref P L0: 49.7% 15.2% 14.8% 20.3%
# [libx264 @ 0x55a5504ddfc0] ref B L0: 68.0% 30.1%  1.9%
# [libx264 @ 0x55a5504ddfc0] ref B L1: 85.7% 14.3%
# [libx264 @ 0x55a5504ddfc0] kb/s:864.13
# 100%|██████████| 80/80 [04:21<00:00,  3.27s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/7ec2f6aca035e69077eab24383a21cb6/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55ec4c923fc0] using SAR=1/1
# [libx264 @ 0x55ec4c923fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55ec4c923fc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55ec4c923fc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-esl_max-shear-0.03_id-7ec2f6aca035e69077eab24383a21cb6.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps=0.0 q=-1.0 Lsize=     878kB time=00:00:07.70 bitrate= 934.5kbits/s speed=  14x
# video:877kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.201196%
# [libx264 @ 0x55ec4c923fc0] frame I:1     Avg QP:15.07  size:151333
# [libx264 @ 0x55ec4c923fc0] frame P:20    Avg QP:17.70  size: 30401
# [libx264 @ 0x55ec4c923fc0] frame B:59    Avg QP:26.55  size:  2332
# [libx264 @ 0x55ec4c923fc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x55ec4c923fc0] mb I  I16..4: 43.8%  0.0% 56.2%
# [libx264 @ 0x55ec4c923fc0] mb P  I16..4:  0.9%  0.0%  1.3%  P16..4: 19.0% 12.8% 14.1%  0.0%  0.0%    skip:51.9%
# [libx264 @ 0x55ec4c923fc0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 17.6%  4.3%  1.1%  direct: 2.0%  skip:74.9%  L0:43.2% L1:37.4% BI:19.3%
# [libx264 @ 0x55ec4c923fc0] coded y,u,v intra: 46.6% 44.4% 43.4% inter: 10.7% 4.9% 3.9%
# [libx264 @ 0x55ec4c923fc0] i16 v,h,dc,p: 86%  9%  6%  0%
# [libx264 @ 0x55ec4c923fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 29% 17%  6%  7%  6%  8%  5%  9%
# [libx264 @ 0x55ec4c923fc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55ec4c923fc0] ref P L0: 47.2% 14.8% 13.3% 24.7%
# [libx264 @ 0x55ec4c923fc0] ref B L0: 66.9% 29.8%  3.3%
# [libx264 @ 0x55ec4c923fc0] ref B L1: 77.9% 22.1%
# [libx264 @ 0x55ec4c923fc0] kb/s:896.96
# 100%|██████████| 80/80 [04:22<00:00,  3.28s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/7ec2f6aca035e69077eab24383a21cb6/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55894337afc0] using SAR=1/1
# [libx264 @ 0x55894337afc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55894337afc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55894337afc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-esl_max-shear-0.05_id-7ec2f6aca035e69077eab24383a21cb6.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps=0.0 q=-1.0 Lsize=    1177kB time=00:00:07.70 bitrate=1252.3kbits/s speed=12.6x
# video:1175kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.151388%
# [libx264 @ 0x55894337afc0] frame I:1     Avg QP:16.07  size:123690
# [libx264 @ 0x55894337afc0] frame P:20    Avg QP:18.32  size: 34267
# [libx264 @ 0x55894337afc0] frame B:59    Avg QP:26.26  size:  6675
# [libx264 @ 0x55894337afc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x55894337afc0] mb I  I16..4: 43.5%  0.0% 56.5%
# [libx264 @ 0x55894337afc0] mb P  I16..4:  1.0%  0.0%  2.5%  P16..4: 17.3% 13.7% 13.7%  0.0%  0.0%    skip:51.8%
# [libx264 @ 0x55894337afc0] mb B  I16..4:  0.0%  0.0%  0.3%  B16..8: 20.0%  7.6%  2.8%  direct: 4.2%  skip:65.1%  L0:43.2% L1:36.2% BI:20.6%
# [libx264 @ 0x55894337afc0] coded y,u,v intra: 57.0% 55.1% 53.7% inter: 18.5% 7.2% 8.5%
# [libx264 @ 0x55894337afc0] i16 v,h,dc,p: 86%  8%  5%  0%
# [libx264 @ 0x55894337afc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 24% 18%  7%  8%  7%  9%  6% 10%
# [libx264 @ 0x55894337afc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55894337afc0] ref P L0: 36.6% 15.4% 17.5% 30.5%
# [libx264 @ 0x55894337afc0] ref B L0: 67.4% 23.6%  8.9%
# [libx264 @ 0x55894337afc0] ref B L1: 83.3% 16.7%
# [libx264 @ 0x55894337afc0] kb/s:1202.86
# 100%|██████████| 80/80 [04:24<00:00,  3.30s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/7ec2f6aca035e69077eab24383a21cb6/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5624d1166fc0] using SAR=1/1
# [libx264 @ 0x5624d1166fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5624d1166fc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x5624d1166fc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-esl_max-shear-0.08_id-7ec2f6aca035e69077eab24383a21cb6.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps=0.0 q=-1.0 Lsize=    3492kB time=00:00:07.70 bitrate=3715.4kbits/s speed= 8.9x
# video:3490kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.051871%
# [libx264 @ 0x5624d1166fc0] frame I:1     Avg QP:17.03  size:104605
# [libx264 @ 0x5624d1166fc0] frame P:20    Avg QP:20.07  size: 62812
# [libx264 @ 0x5624d1166fc0] frame B:59    Avg QP:26.48  size: 37504
# [libx264 @ 0x5624d1166fc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x5624d1166fc0] mb I  I16..4: 43.4%  0.0% 56.6%
# [libx264 @ 0x5624d1166fc0] mb P  I16..4:  1.1%  0.0% 18.9%  P16..4:  5.9%  9.6% 13.3%  0.0%  0.0%    skip:51.3%
# [libx264 @ 0x5624d1166fc0] mb B  I16..4:  0.0%  0.0%  7.7%  B16..8: 12.0% 13.0%  9.5%  direct: 4.4%  skip:53.3%  L0:40.1% L1:33.1% BI:26.8%
# [libx264 @ 0x5624d1166fc0] coded y,u,v intra: 90.7% 90.8% 86.9% inter: 34.3% 20.2% 24.8%
# [libx264 @ 0x5624d1166fc0] i16 v,h,dc,p: 86%  7%  7%  0%
# [libx264 @ 0x5624d1166fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11% 17% 17%  8% 10%  8% 11%  7% 11%
# [libx264 @ 0x5624d1166fc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5624d1166fc0] ref P L0: 31.4% 19.3% 27.7% 21.7%
# [libx264 @ 0x5624d1166fc0] ref B L0: 72.6% 20.8%  6.6%
# [libx264 @ 0x5624d1166fc0] ref B L1: 87.9% 12.1%
# [libx264 @ 0x5624d1166fc0] kb/s:3573.55
# 100%|██████████| 80/80 [04:24<00:00,  3.31s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/7ec2f6aca035e69077eab24383a21cb6/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x555b1fb50fc0] using SAR=1/1
# [libx264 @ 0x555b1fb50fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x555b1fb50fc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x555b1fb50fc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-esl_max-shear-0.12_id-7ec2f6aca035e69077eab24383a21cb6.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps= 75 q=-1.0 Lsize=    5217kB time=00:00:07.70 bitrate=5550.7kbits/s speed=7.22x
# video:5216kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.034639%
# [libx264 @ 0x555b1fb50fc0] frame I:1     Avg QP:17.62  size: 93362
# [libx264 @ 0x555b1fb50fc0] frame P:20    Avg QP:20.86  size: 73182
# [libx264 @ 0x555b1fb50fc0] frame B:59    Avg QP:26.26  size: 64120
# [libx264 @ 0x555b1fb50fc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x555b1fb50fc0] mb I  I16..4: 43.3%  0.0% 56.7%
# [libx264 @ 0x555b1fb50fc0] mb P  I16..4:  1.0%  0.0% 36.2%  P16..4:  1.8%  3.0%  6.7%  0.0%  0.0%    skip:51.3%
# [libx264 @ 0x555b1fb50fc0] mb B  I16..4:  0.1%  0.0% 27.5%  B16..8:  3.7%  7.1%  7.9%  direct: 1.2%  skip:52.6%  L0:41.3% L1:30.8% BI:27.9%
# [libx264 @ 0x555b1fb50fc0] coded y,u,v intra: 95.6% 96.0% 92.2% inter: 22.6% 18.8% 19.0%
# [libx264 @ 0x555b1fb50fc0] i16 v,h,dc,p: 83%  7%  8%  2%
# [libx264 @ 0x555b1fb50fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11% 17% 16%  8% 10%  8% 11%  7% 11%
# [libx264 @ 0x555b1fb50fc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x555b1fb50fc0] ref P L0: 29.4% 16.1% 28.1% 26.3%
# [libx264 @ 0x555b1fb50fc0] ref B L0: 70.4% 22.2%  7.4%
# [libx264 @ 0x555b1fb50fc0] ref B L1: 86.1% 13.9%
# [libx264 @ 0x555b1fb50fc0] kb/s:5340.09
# cfa1e4c0007fd65d020f809715a6f0b4
# ecce68c50e28a33684826f28780bf6e9
# 1d0fe2ba44a6f635f5504dcbcee0ebc9
# ESL
# 100%|██████████| 80/80 [04:23<00:00,  3.30s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/1d0fe2ba44a6f635f5504dcbcee0ebc9/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x56279f0d1fc0] using SAR=1/1
# [libx264 @ 0x56279f0d1fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x56279f0d1fc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x56279f0d1fc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-esl_max-shear-0.01_id-1d0fe2ba44a6f635f5504dcbcee0ebc9.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps=0.0 q=-1.0 Lsize=     879kB time=00:00:07.70 bitrate= 935.5kbits/s speed=13.8x
# video:878kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.201873%
# [libx264 @ 0x56279f0d1fc0] frame I:1     Avg QP:14.55  size:169674
# [libx264 @ 0x56279f0d1fc0] frame P:21    Avg QP:17.59  size: 29612
# [libx264 @ 0x56279f0d1fc0] frame B:58    Avg QP:26.76  size:  1834
# [libx264 @ 0x56279f0d1fc0] consecutive B-frames:  2.5%  2.5%  0.0% 95.0%
# [libx264 @ 0x56279f0d1fc0] mb I  I16..4: 43.5%  0.0% 56.5%
# [libx264 @ 0x56279f0d1fc0] mb P  I16..4:  1.0%  0.0%  1.0%  P16..4: 17.9% 12.9% 15.2%  0.0%  0.0%    skip:52.1%
# [libx264 @ 0x56279f0d1fc0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 15.5%  3.8%  0.9%  direct: 1.8%  skip:77.9%  L0:44.4% L1:34.6% BI:21.0%
# [libx264 @ 0x56279f0d1fc0] coded y,u,v intra: 43.4% 40.7% 40.3% inter: 10.0% 5.0% 3.4%
# [libx264 @ 0x56279f0d1fc0] i16 v,h,dc,p: 87%  8%  5%  0%
# [libx264 @ 0x56279f0d1fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 29% 17%  5%  7%  6%  8%  6%  9%
# [libx264 @ 0x56279f0d1fc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x56279f0d1fc0] ref P L0: 49.2% 14.7% 14.3% 21.9%
# [libx264 @ 0x56279f0d1fc0] ref B L0: 68.3% 31.3%  0.4%
# [libx264 @ 0x56279f0d1fc0] ref B L1: 82.9% 17.1%
# [libx264 @ 0x56279f0d1fc0] kb/s:897.91
# 100%|██████████| 80/80 [04:25<00:00,  3.32s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/1d0fe2ba44a6f635f5504dcbcee0ebc9/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x563987a53fc0] using SAR=1/1
# [libx264 @ 0x563987a53fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x563987a53fc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x563987a53fc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-esl_max-shear-0.02_id-1d0fe2ba44a6f635f5504dcbcee0ebc9.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps=0.0 q=-1.0 Lsize=     875kB time=00:00:07.70 bitrate= 931.0kbits/s speed=13.3x
# video:873kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.201958%
# [libx264 @ 0x563987a53fc0] frame I:1     Avg QP:14.73  size:163583
# [libx264 @ 0x563987a53fc0] frame P:20    Avg QP:17.69  size: 31117
# [libx264 @ 0x563987a53fc0] frame B:59    Avg QP:26.86  size:  1824
# [libx264 @ 0x563987a53fc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x563987a53fc0] mb I  I16..4: 43.5%  0.0% 56.5%
# [libx264 @ 0x563987a53fc0] mb P  I16..4:  1.0%  0.0%  1.1%  P16..4: 18.5% 12.8% 14.8%  0.0%  0.0%    skip:51.8%
# [libx264 @ 0x563987a53fc0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 15.9%  3.8%  0.9%  direct: 1.7%  skip:77.6%  L0:44.7% L1:35.2% BI:20.2%
# [libx264 @ 0x563987a53fc0] coded y,u,v intra: 44.4% 41.6% 41.8% inter: 9.9% 5.0% 3.4%
# [libx264 @ 0x563987a53fc0] i16 v,h,dc,p: 86%  8%  6%  0%
# [libx264 @ 0x563987a53fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 29% 17%  5%  7%  6%  8%  5%  9%
# [libx264 @ 0x563987a53fc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x563987a53fc0] ref P L0: 51.5% 15.6% 14.5% 18.3%
# [libx264 @ 0x563987a53fc0] ref B L0: 70.9% 27.6%  1.5%
# [libx264 @ 0x563987a53fc0] ref B L1: 84.0% 16.0%
# [libx264 @ 0x563987a53fc0] kb/s:893.57
# 100%|██████████| 80/80 [04:25<00:00,  3.32s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/1d0fe2ba44a6f635f5504dcbcee0ebc9/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55f719d7efc0] using SAR=1/1
# [libx264 @ 0x55f719d7efc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55f719d7efc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55f719d7efc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-esl_max-shear-0.03_id-1d0fe2ba44a6f635f5504dcbcee0ebc9.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps=0.0 q=-1.0 Lsize=     932kB time=00:00:07.70 bitrate= 991.5kbits/s speed=13.9x
# video:930kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.189607%
# [libx264 @ 0x55f719d7efc0] frame I:1     Avg QP:15.19  size:150432
# [libx264 @ 0x55f719d7efc0] frame P:20    Avg QP:17.61  size: 31238
# [libx264 @ 0x55f719d7efc0] frame B:59    Avg QP:26.41  size:  2994
# [libx264 @ 0x55f719d7efc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x55f719d7efc0] mb I  I16..4: 43.6%  0.0% 56.4%
# [libx264 @ 0x55f719d7efc0] mb P  I16..4:  1.1%  0.0%  1.2%  P16..4: 18.4% 13.0% 14.0%  0.0%  0.0%    skip:52.3%
# [libx264 @ 0x55f719d7efc0] mb B  I16..4:  0.0%  0.0%  0.1%  B16..8: 17.9%  5.0%  1.3%  direct: 2.5%  skip:73.2%  L0:45.3% L1:34.7% BI:20.0%
# [libx264 @ 0x55f719d7efc0] coded y,u,v intra: 45.9% 43.7% 43.2% inter: 12.1% 5.3% 4.5%
# [libx264 @ 0x55f719d7efc0] i16 v,h,dc,p: 86%  9%  6%  0%
# [libx264 @ 0x55f719d7efc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 28% 17%  6%  7%  7%  8%  6%  9%
# [libx264 @ 0x55f719d7efc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55f719d7efc0] ref P L0: 46.8% 15.8% 13.3% 24.0%
# [libx264 @ 0x55f719d7efc0] ref B L0: 66.5% 29.7%  3.9%
# [libx264 @ 0x55f719d7efc0] ref B L1: 78.9% 21.1%
# [libx264 @ 0x55f719d7efc0] kb/s:951.82
# 100%|██████████| 80/80 [04:26<00:00,  3.34s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/1d0fe2ba44a6f635f5504dcbcee0ebc9/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55cf2ef89fc0] using SAR=1/1
# [libx264 @ 0x55cf2ef89fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55cf2ef89fc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55cf2ef89fc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-esl_max-shear-0.05_id-1d0fe2ba44a6f635f5504dcbcee0ebc9.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps=0.0 q=-1.0 Lsize=    1239kB time=00:00:07.70 bitrate=1318.2kbits/s speed=12.4x
# video:1237kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.143813%
# [libx264 @ 0x55cf2ef89fc0] frame I:1     Avg QP:15.76  size:135084
# [libx264 @ 0x55cf2ef89fc0] frame P:20    Avg QP:18.27  size: 34970
# [libx264 @ 0x55cf2ef89fc0] frame B:59    Avg QP:26.40  size:  7318
# [libx264 @ 0x55cf2ef89fc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x55cf2ef89fc0] mb I  I16..4: 43.4%  0.0% 56.6%
# [libx264 @ 0x55cf2ef89fc0] mb P  I16..4:  1.0%  0.0%  2.2%  P16..4: 16.5% 14.0% 14.5%  0.0%  0.0%    skip:51.8%
# [libx264 @ 0x55cf2ef89fc0] mb B  I16..4:  0.0%  0.0%  0.3%  B16..8: 19.4%  7.9%  3.1%  direct: 4.6%  skip:64.8%  L0:43.7% L1:35.1% BI:21.2%
# [libx264 @ 0x55cf2ef89fc0] coded y,u,v intra: 56.2% 54.8% 52.9% inter: 20.0% 7.4% 9.5%
# [libx264 @ 0x55cf2ef89fc0] i16 v,h,dc,p: 86%  8%  6%  0%
# [libx264 @ 0x55cf2ef89fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 24% 17%  7%  8%  7%  9%  6% 10%
# [libx264 @ 0x55cf2ef89fc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55cf2ef89fc0] ref P L0: 34.8% 15.0% 20.6% 29.5%
# [libx264 @ 0x55cf2ef89fc0] ref B L0: 64.5% 24.7% 10.8%
# [libx264 @ 0x55cf2ef89fc0] ref B L1: 83.5% 16.5%
# [libx264 @ 0x55cf2ef89fc0] kb/s:1266.25
# 100%|██████████| 80/80 [04:26<00:00,  3.33s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/1d0fe2ba44a6f635f5504dcbcee0ebc9/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x560cb6c82fc0] using SAR=1/1
# [libx264 @ 0x560cb6c82fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x560cb6c82fc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x560cb6c82fc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-esl_max-shear-0.08_id-1d0fe2ba44a6f635f5504dcbcee0ebc9.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps=0.0 q=-1.0 Lsize=    3714kB time=00:00:07.70 bitrate=3951.5kbits/s speed= 8.4x
# video:3712kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.048454%
# [libx264 @ 0x560cb6c82fc0] frame I:1     Avg QP:17.05  size:106027
# [libx264 @ 0x560cb6c82fc0] frame P:20    Avg QP:20.50  size: 64999
# [libx264 @ 0x560cb6c82fc0] frame B:59    Avg QP:26.77  size: 40591
# [libx264 @ 0x560cb6c82fc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x560cb6c82fc0] mb I  I16..4: 43.3%  0.0% 56.7%
# [libx264 @ 0x560cb6c82fc0] mb P  I16..4:  0.9%  0.0% 19.9%  P16..4:  5.5%  8.9% 13.3%  0.0%  0.0%    skip:51.4%
# [libx264 @ 0x560cb6c82fc0] mb B  I16..4:  0.0%  0.0%  8.9%  B16..8: 10.9% 12.8%  9.9%  direct: 4.3%  skip:53.1%  L0:40.2% L1:31.8% BI:28.0%
# [libx264 @ 0x560cb6c82fc0] coded y,u,v intra: 91.6% 91.8% 88.1% inter: 34.8% 20.8% 25.3%
# [libx264 @ 0x560cb6c82fc0] i16 v,h,dc,p: 87%  7%  6%  1%
# [libx264 @ 0x560cb6c82fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 17% 17%  8% 10%  8% 11%  7% 11%
# [libx264 @ 0x560cb6c82fc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x560cb6c82fc0] ref P L0: 30.6% 18.5% 28.1% 22.8%
# [libx264 @ 0x560cb6c82fc0] ref B L0: 72.5% 20.5%  7.0%
# [libx264 @ 0x560cb6c82fc0] ref B L1: 88.2% 11.8%
# [libx264 @ 0x560cb6c82fc0] kb/s:3800.85
# 100%|██████████| 80/80 [04:28<00:00,  3.36s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
# ...
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55ad15dc7fc0] using SAR=1/1
# [libx264 @ 0x55ad15dc7fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55ad15dc7fc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55ad15dc7fc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-esl_max-shear-0.01_id-a8f2c249ed85533b56b0729b7ab96d18.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps=0.0 q=-1.0 Lsize=     891kB time=00:00:07.70 bitrate= 947.9kbits/s speed=13.5x
# video:889kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.198341%
# [libx264 @ 0x55ad15dc7fc0] frame I:1     Avg QP:14.54  size:169881
# [libx264 @ 0x55ad15dc7fc0] frame P:20    Avg QP:17.48  size: 31669
# [libx264 @ 0x55ad15dc7fc0] frame B:59    Avg QP:26.89  size:  1807
# [libx264 @ 0x55ad15dc7fc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x55ad15dc7fc0] mb I  I16..4: 43.4%  0.0% 56.6%
# [libx264 @ 0x55ad15dc7fc0] mb P  I16..4:  0.9%  0.0%  1.1%  P16..4: 16.7% 13.2% 16.0%  0.0%  0.0%    skip:52.1%
# [libx264 @ 0x55ad15dc7fc0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 14.5%  3.6%  0.8%  direct: 1.9%  skip:79.2%  L0:42.1% L1:35.3% BI:22.7%
# [libx264 @ 0x55ad15dc7fc0] coded y,u,v intra: 44.3% 41.9% 41.7% inter: 10.0% 5.0% 3.3%
# [libx264 @ 0x55ad15dc7fc0] i16 v,h,dc,p: 88%  7%  5%  0%
# [libx264 @ 0x55ad15dc7fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 29% 17%  5%  7%  6%  8%  5%  9%
# [libx264 @ 0x55ad15dc7fc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55ad15dc7fc0] ref P L0: 47.5% 14.4% 18.9% 19.2%
# [libx264 @ 0x55ad15dc7fc0] ref B L0: 68.1% 30.3%  1.6%
# [libx264 @ 0x55ad15dc7fc0] ref B L1: 83.9% 16.1%
# [libx264 @ 0x55ad15dc7fc0] kb/s:909.88
# 100%|██████████| 80/80 [04:33<00:00,  3.41s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/a8f2c249ed85533b56b0729b7ab96d18/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x557c51f63fc0] using SAR=1/1
# [libx264 @ 0x557c51f63fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x557c51f63fc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x557c51f63fc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-esl_max-shear-0.02_id-a8f2c249ed85533b56b0729b7ab96d18.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps=0.0 q=-1.0 Lsize=     900kB time=00:00:07.70 bitrate= 957.3kbits/s speed=13.1x
# video:898kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.196378%
# [libx264 @ 0x557c51f63fc0] frame I:1     Avg QP:14.77  size:164091
# [libx264 @ 0x557c51f63fc0] frame P:20    Avg QP:17.60  size: 31246
# [libx264 @ 0x557c51f63fc0] frame B:59    Avg QP:26.91  size:  2203
# [libx264 @ 0x557c51f63fc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x557c51f63fc0] mb I  I16..4: 43.5%  0.0% 56.5%
# [libx264 @ 0x557c51f63fc0] mb P  I16..4:  1.0%  0.0%  1.1%  P16..4: 18.3% 12.9% 14.9%  0.0%  0.0%    skip:51.9%
# [libx264 @ 0x557c51f63fc0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 16.6%  4.2%  1.1%  direct: 2.0%  skip:76.1%  L0:43.1% L1:35.6% BI:21.3%
# [libx264 @ 0x557c51f63fc0] coded y,u,v intra: 44.7% 42.1% 41.9% inter: 10.6% 4.9% 3.6%
# [libx264 @ 0x557c51f63fc0] i16 v,h,dc,p: 86%  8%  6%  0%
# [libx264 @ 0x557c51f63fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 29% 17%  5%  7%  6%  8%  5%  9%
# [libx264 @ 0x557c51f63fc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x557c51f63fc0] ref P L0: 49.6% 15.8% 13.9% 20.7%
# [libx264 @ 0x557c51f63fc0] ref B L0: 65.0% 32.1%  2.9%
# [libx264 @ 0x557c51f63fc0] ref B L1: 77.8% 22.2%
# [libx264 @ 0x557c51f63fc0] kb/s:918.98
# 100%|██████████| 80/80 [04:33<00:00,  3.42s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/a8f2c249ed85533b56b0729b7ab96d18/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55ff68418fc0] using SAR=1/1
# [libx264 @ 0x55ff68418fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55ff68418fc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55ff68418fc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-esl_max-shear-0.03_id-a8f2c249ed85533b56b0729b7ab96d18.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps=0.0 q=-1.0 Lsize=     918kB time=00:00:07.70 bitrate= 976.6kbits/s speed=13.9x
# video:916kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.193361%
# [libx264 @ 0x55ff68418fc0] frame I:1     Avg QP:14.99  size:157301
# [libx264 @ 0x55ff68418fc0] frame P:21    Avg QP:17.73  size: 29830
# [libx264 @ 0x55ff68418fc0] frame B:58    Avg QP:26.25  size:  2651
# [libx264 @ 0x55ff68418fc0] consecutive B-frames:  2.5%  2.5%  0.0% 95.0%
# [libx264 @ 0x55ff68418fc0] mb I  I16..4: 43.4%  0.0% 56.6%
# [libx264 @ 0x55ff68418fc0] mb P  I16..4:  1.0%  0.0%  1.2%  P16..4: 19.4% 12.4% 13.9%  0.0%  0.0%    skip:52.1%
# [libx264 @ 0x55ff68418fc0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 17.6%  4.6%  1.2%  direct: 2.3%  skip:74.3%  L0:43.6% L1:35.8% BI:20.7%
# [libx264 @ 0x55ff68418fc0] coded y,u,v intra: 45.2% 42.6% 42.4% inter: 11.5% 5.0% 4.0%
# [libx264 @ 0x55ff68418fc0] i16 v,h,dc,p: 85%  9%  6%  0%
# [libx264 @ 0x55ff68418fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 28% 17%  5%  7%  6%  8%  5%  9%
# [libx264 @ 0x55ff68418fc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55ff68418fc0] ref P L0: 48.6% 15.1% 12.5% 23.8%
# [libx264 @ 0x55ff68418fc0] ref B L0: 68.2% 30.2%  1.6%
# [libx264 @ 0x55ff68418fc0] ref B L1: 80.2% 19.8%
# [libx264 @ 0x55ff68418fc0] kb/s:937.46
# 100%|██████████| 80/80 [04:37<00:00,  3.47s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/a8f2c249ed85533b56b0729b7ab96d18/videos/softness-movie-strob/softness-movie-*.png':
#   Duration: 00:00:08.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x556a00ffafc0] using SAR=1/1
# [libx264 @ 0x556a00ffafc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x556a00ffafc0] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x556a00ffafc0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-strob-esl_max-shear-0.05_id-a8f2c249ed85533b56b0729b7ab96d18.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   80 fps=0.0 q=-1.0 Lsize=    1202kB time=00:00:07.70 bitrate=1278.8kbits/s speed=12.6x
# video:1200kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.148249%
# [libx264 @ 0x556a00ffafc0] frame I:1     Avg QP:15.51  size:142211
# [libx264 @ 0x556a00ffafc0] frame P:20    Avg QP:18.21  size: 35229
# [libx264 @ 0x556a00ffafc0] frame B:59    Avg QP:25.78  size:  6467
# [libx264 @ 0x556a00ffafc0] consecutive B-frames:  1.2%  0.0%  3.8% 95.0%
# [libx264 @ 0x556a00ffafc0] mb I  I16..4: 43.3%  0.0% 56.7%
# [libx264 @ 0x556a00ffafc0] mb P  I16..4:  1.0%  0.0%  1.8%  P16..4: 17.5% 13.9% 14.1%  0.0%  0.0%    skip:51.7%
# [libx264 @ 0x556a00ffafc0] mb B  I16..4:  0.0%  0.0%  0.2%  B16..8: 19.8%  7.4%  2.9%  direct: 4.3%  skip:65.4%  L0:44.5% L1:34.7% BI:20.8%
# [libx264 @ 0x556a00ffafc0] coded y,u,v intra: 52.6% 51.0% 49.7% inter: 19.3% 7.0% 8.8%
# [libx264 @ 0x556a00ffafc0] i16 v,h,dc,p: 86%  9%  6%  0%
# [libx264 @ 0x556a00ffafc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 25% 17%  6%  8%  7%  9%  6% 10%
# [libx264 @ 0x556a00ffafc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x556a00ffafc0] ref P L0: 36.2% 18.2% 18.0% 27.5%
# [libx264 @ 0x556a00ffafc0] ref B L0: 67.2% 24.0%  8.8%
# [libx264 @ 0x556a00ffafc0] ref B L1: 82.7% 17.3%
# [libx264 @ 0x556a00ffafc0] kb/s:1228.34
#  16%|█▋        | 13/80 [00:44<03:48,  3.42s/it]

# %%
job.id
# Out:
# '7ec2f6aca035e69077eab24383a21cb6'
