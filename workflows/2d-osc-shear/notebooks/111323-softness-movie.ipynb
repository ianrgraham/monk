# %%
import numpy as np
import pandas as pd
import polars as pl
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import cm, colors

import glob
import gc
import warnings
import copy
import pathlib
import pickle

import os
import shutil

from scipy import stats
import signac
import freud
import gsd.hoomd
import hoomd
import schmeud
import schmeud._schmeud as schmeud_rs
from schmeud._schmeud import statics
from schmeud import ml
from tqdm import tqdm

from dataclasses import dataclass
from collections import defaultdict

from numba import njit

import seaborn as sns
from matplotlib.collections import PatchCollection
from matplotlib.patches import Circle

# %%
from monk import nb, prep, pair, render, utils, workflow, grid

parent = pathlib.Path(os.getcwd()).parent / "config.yaml"
config = workflow.get_config(parent.as_posix())
parent, config
# Out:
# (PosixPath('/home/ian/Projects/work/monk/workflows/2d-osc-shear/config.yaml'),
#  {'root': '/media/ian/Data2/monk/2d-osc-shear',
#   'origin': '/media/ian/Data2/monk/2d-esl'})

# %%
project: signac.Project = signac.get_project(root=config['root'])
project.doc
# Out:
# {'avail_seed': 18, 'dt': 0.005, 'step_unit': 200, 'equil_time': 100, 'min_periods': 20, 'dumps': 40, 'period_times': [30.0, 100.0, 300.0, 1000.0], 'max_shears': [0.01, 0.02, 0.03, 0.05, 0.08, 0.12], '_status': {}}

# %%
@dataclass(frozen=True, eq=True)
class Statepoint:
    max_shear: float
    period: float
    temp: float
    prep: str

# %%
def plot_data(snap, data, ax=None, lim=None):

    if ax is None:
        fig, ax = plt.subplots()
    else:
        fig = ax.get_figure()

    # extract particle positions and data
    positions = snap.particles.position
    diams = snap.particles.diameter
    color_data = data
    # color_data = np.abs(soft_ffts[:,2:20]).sum(axis=-1)

    # create a list of circles with positions and radius
    circles = [Circle((x[0], x[1]), radius=d/2.0) for x, d in zip(positions, diams)]

    # create a patch collection with circles and color data
    norm = colors.Normalize(-2, 2)
    
    cmap = sns.color_palette("Spectral", as_cmap=True)
    collection = PatchCollection(circles, cmap=cmap, norm=norm)
    collection.set_array(color_data)

    # plot particles with color
    # fig, ax = plt.subplots()
    ax.add_collection(collection)
    ax.autoscale()

    # zoom in 5x
    if lim is None:
        zoom = 4
        xlim = ax.get_xlim()
        ylim = ax.get_ylim()
        ax.set_xlim((xlim[0] + xlim[1])/2 - (xlim[1] - xlim[0])/zoom/2, (xlim[0] + xlim[1])/2 + (xlim[1] - xlim[0])/zoom/2)
        ax.set_ylim((ylim[0] + ylim[1])/2 - (ylim[1] - ylim[0])/zoom/2, (ylim[0] + ylim[1])/2 + (ylim[1] - ylim[0])/zoom/2)
    else:
        ax.set_xlim(-lim, lim)
        ax.set_ylim(-lim, lim)

    # check if has colorbar
    if ax.get_figure().get_axes()[-1] == ax:
        plt.colorbar(collection, label="Softness")

# %%
output = defaultdict(list)

for job in project:
    print(job)
    prep = job.sp["prep"]
    if prep != "ESL":
        continue
    print(prep)
    
    experiments = sorted(glob.glob(job.fn("aqs_therm_experiments/*/*/traj-fire_period-*.gsd")))
    if len(experiments) == 0:
        continue
    for exper in experiments:
        max_shear = utils.extract_between(exper, "max-shear-", "/")
        period = utils.extract_between(exper, "period-", ".gsd")
        temp = utils.extract_between(exper, "temp-", "/")
        df_path = f"aqs_therm_experiments/max-shear-{max_shear}/temp-{temp}/final-cycles-softness_period-{period}.parquet"
        new_df_path = f"aqs_therm_experiments/max-shear-{max_shear}/temp-{temp}/ave-softness-fft-abs_period-{period}.parquet"
        sp = Statepoint(max_shear=float(max_shear), period=float(period), temp=float(temp), prep=prep)
        
        if float(period) != 1000.0 or float(temp) > 5e-3:
            continue

        if job.isfile(df_path):
            dataset = pl.read_parquet(job.fn(df_path), use_pyarrow=True)
        else:
            continue
        
        traj = gsd.hoomd.open(exper)
        
        # softs = np.stack(dataset["soft"].to_numpy())
        # nsofts = softs.reshape(5, 40, 32768)
        # nsofts = nsofts.mean(axis=0)

        # compute fft
        # soft_ffts = np.fft.fft(nsofts.T, axis=-1)

        output_file = f"videos/softness-movie-esl_max-shear-{max_shear}_id-{job.id}.mp4"
        print(output_file)
        if os.path.exists(output_file):
            print("already exists")
            continue
        else:
            print("does not exist, running")

        # output[sp].append(soft_ffts)
        fig, ax = plt.subplots()
        frame_path = job.fn("videos/softness-movie/")
        if os.path.exists(frame_path):
            shutil.rmtree(frame_path)
        os.makedirs(job.fn("videos/softness-movie/"), exist_ok=True)
        # i = 0
        for frame, _, soft in tqdm(dataset.rows()):
            # print(frame)
            # if i == 2:
            #     break
            snap = traj[frame]
            name = job.fn("videos/softness-movie/softness-movie-{:04d}.png".format(frame))
            if os.path.exists(name):
                continue

            plot_data(snap, soft, ax=ax, lim=40)
            plt.savefig(name, dpi=150)
            # clear axis
            ax.cla()

        import ffmpeg
        (
        ffmpeg
            .input(job.fn("videos/softness-movie/softness-movie-*.png"), pattern_type="glob", framerate=10)
            .output(output_file).run()
        )
        # break
    # break
# Out:
# 634e14bc75836df75158fb15f379d8bb
# 7ec2f6aca035e69077eab24383a21cb6
# ESL
# videos/softness-movie-esl_max-shear-0.01_id-7ec2f6aca035e69077eab24383a21cb6.mp4
# does not exist, running
# 100%|██████████| 201/201 [10:57<00:00,  3.27s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/7ec2f6aca035e69077eab24383a21cb6/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x56408195d240] using SAR=1/1
# [libx264 @ 0x56408195d240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x56408195d240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x56408195d240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-esl_max-shear-0.01_id-7ec2f6aca035e69077eab24383a21cb6.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=188 q=-1.0 Lsize=    1604kB time=00:00:19.80 bitrate= 663.6kbits/s speed=18.6x
# video:1601kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.200229%
# [libx264 @ 0x56408195d240] frame I:1     Avg QP:14.26  size:172830
# [libx264 @ 0x56408195d240] frame P:51    Avg QP:17.33  size: 27192
# [libx264 @ 0x56408195d240] frame B:149   Avg QP:19.58  size:   529
# [libx264 @ 0x56408195d240] consecutive B-frames:  0.5%  2.0%  0.0% 97.5%
# [libx264 @ 0x56408195d240] mb I  I16..4: 43.3%  0.0% 56.7%
# [libx264 @ 0x56408195d240] mb P  I16..4:  0.6%  0.0%  0.1%  P16..4: 18.2% 12.7% 15.1%  0.0%  0.0%    skip:53.3%
# [libx264 @ 0x56408195d240] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 17.6%  0.8%  0.2%  direct: 0.3%  skip:81.1%  L0:35.5% L1:48.4% BI:16.2%
# [libx264 @ 0x56408195d240] coded y,u,v intra: 39.4% 36.9% 38.1% inter: 8.8% 4.6% 4.3%
# [libx264 @ 0x56408195d240] i16 v,h,dc,p: 87%  8%  5%  0%
# [libx264 @ 0x56408195d240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17% 19% 13%  7%  9%  7%  9%  7% 11%
# [libx264 @ 0x56408195d240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x56408195d240] ref P L0: 58.2% 21.0% 11.2%  9.7%
# [libx264 @ 0x56408195d240] ref B L0: 76.8% 16.7%  6.5%
# [libx264 @ 0x56408195d240] ref B L1: 88.1% 11.9%
# [libx264 @ 0x56408195d240] kb/s:652.12
# videos/softness-movie-esl_max-shear-0.02_id-7ec2f6aca035e69077eab24383a21cb6.mp4
# does not exist, running
# 100%|██████████| 201/201 [10:54<00:00,  3.26s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/7ec2f6aca035e69077eab24383a21cb6/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55a87dbb0240] using SAR=1/1
# [libx264 @ 0x55a87dbb0240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55a87dbb0240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55a87dbb0240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-esl_max-shear-0.02_id-7ec2f6aca035e69077eab24383a21cb6.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=195 q=-1.0 Lsize=    1950kB time=00:00:19.80 bitrate= 806.9kbits/s speed=19.2x
# video:1947kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.164613%
# [libx264 @ 0x55a87dbb0240] frame I:1     Avg QP:14.78  size:157107
# [libx264 @ 0x55a87dbb0240] frame P:50    Avg QP:17.62  size: 33579
# [libx264 @ 0x55a87dbb0240] frame B:150   Avg QP:24.41  size:  1047
# [libx264 @ 0x55a87dbb0240] consecutive B-frames:  0.5%  0.0%  0.0% 99.5%
# [libx264 @ 0x55a87dbb0240] mb I  I16..4: 43.4%  0.0% 56.6%
# [libx264 @ 0x55a87dbb0240] mb P  I16..4:  0.8%  0.0%  0.2%  P16..4: 16.0% 15.0% 16.1%  0.0%  0.0%    skip:51.9%
# [libx264 @ 0x55a87dbb0240] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 20.4%  2.0%  0.6%  direct: 1.0%  skip:76.0%  L0:29.8% L1:46.8% BI:23.5%
# [libx264 @ 0x55a87dbb0240] coded y,u,v intra: 39.5% 38.2% 38.1% inter: 10.5% 5.3% 5.6%
# [libx264 @ 0x55a87dbb0240] i16 v,h,dc,p: 87%  9%  4%  0%
# [libx264 @ 0x55a87dbb0240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 20% 14%  7%  9%  8% 10%  6% 11%
# [libx264 @ 0x55a87dbb0240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55a87dbb0240] ref P L0: 54.3% 25.5%  9.4% 10.9%
# [libx264 @ 0x55a87dbb0240] ref B L0: 82.2% 11.3%  6.5%
# [libx264 @ 0x55a87dbb0240] ref B L1: 90.0% 10.0%
# [libx264 @ 0x55a87dbb0240] kb/s:793.27
# videos/softness-movie-esl_max-shear-0.03_id-7ec2f6aca035e69077eab24383a21cb6.mp4
# does not exist, running
# 100%|██████████| 201/201 [10:51<00:00,  3.24s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/7ec2f6aca035e69077eab24383a21cb6/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5559d20b1240] using SAR=1/1
# [libx264 @ 0x5559d20b1240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5559d20b1240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x5559d20b1240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-esl_max-shear-0.03_id-7ec2f6aca035e69077eab24383a21cb6.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=182 q=-1.0 Lsize=    2400kB time=00:00:19.80 bitrate= 992.8kbits/s speed=17.9x
# video:2396kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.134071%
# [libx264 @ 0x5559d20b1240] frame I:1     Avg QP:15.39  size:140135
# [libx264 @ 0x5559d20b1240] frame P:53    Avg QP:17.88  size: 38618
# [libx264 @ 0x5559d20b1240] frame B:147   Avg QP:25.45  size:  1812
# [libx264 @ 0x5559d20b1240] consecutive B-frames:  1.0%  4.0%  1.5% 93.5%
# [libx264 @ 0x5559d20b1240] mb I  I16..4: 43.7%  0.0% 56.3%
# [libx264 @ 0x5559d20b1240] mb P  I16..4:  0.9%  0.0%  0.8%  P16..4: 14.5% 15.9% 16.0%  0.0%  0.0%    skip:51.8%
# [libx264 @ 0x5559d20b1240] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 21.7%  3.4%  1.1%  direct: 1.7%  skip:72.1%  L0:30.9% L1:41.7% BI:27.4%
# [libx264 @ 0x5559d20b1240] coded y,u,v intra: 48.2% 47.1% 47.0% inter: 12.9% 6.2% 6.9%
# [libx264 @ 0x5559d20b1240] i16 v,h,dc,p: 84% 10%  6%  0%
# [libx264 @ 0x5559d20b1240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 19% 14%  7%  9%  8% 10%  7% 11%
# [libx264 @ 0x5559d20b1240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5559d20b1240] ref P L0: 53.8% 28.7%  8.5%  9.0%
# [libx264 @ 0x5559d20b1240] ref B L0: 88.6%  8.7%  2.8%
# [libx264 @ 0x5559d20b1240] ref B L1: 92.6%  7.4%
# [libx264 @ 0x5559d20b1240] kb/s:976.42
# videos/softness-movie-esl_max-shear-0.05_id-7ec2f6aca035e69077eab24383a21cb6.mp4
# does not exist, running
# 100%|██████████| 201/201 [10:53<00:00,  3.25s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/7ec2f6aca035e69077eab24383a21cb6/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5630a1ae1240] using SAR=1/1
# [libx264 @ 0x5630a1ae1240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5630a1ae1240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x5630a1ae1240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-esl_max-shear-0.05_id-7ec2f6aca035e69077eab24383a21cb6.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=168 q=-1.0 Lsize=    3160kB time=00:00:19.80 bitrate=1307.4kbits/s speed=16.5x
# video:3157kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.102522%
# [libx264 @ 0x5630a1ae1240] frame I:1     Avg QP:15.98  size:124555
# [libx264 @ 0x5630a1ae1240] frame P:51    Avg QP:18.35  size: 47538
# [libx264 @ 0x5630a1ae1240] frame B:149   Avg QP:26.32  size:  4583
# [libx264 @ 0x5630a1ae1240] consecutive B-frames:  0.5%  2.0%  0.0% 97.5%
# [libx264 @ 0x5630a1ae1240] mb I  I16..4: 43.3%  0.0% 56.7%
# [libx264 @ 0x5630a1ae1240] mb P  I16..4:  1.0%  0.0%  3.1%  P16..4: 12.3% 15.7% 16.4%  0.0%  0.0%    skip:51.6%
# [libx264 @ 0x5630a1ae1240] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 22.1%  6.6%  2.5%  direct: 3.4%  skip:65.5%  L0:31.9% L1:35.0% BI:33.1%
# [libx264 @ 0x5630a1ae1240] coded y,u,v intra: 66.6% 66.3% 64.5% inter: 17.8% 7.9% 9.6%
# [libx264 @ 0x5630a1ae1240] i16 v,h,dc,p: 85% 10%  5%  0%
# [libx264 @ 0x5630a1ae1240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 18% 15%  7% 10%  8% 11%  7% 12%
# [libx264 @ 0x5630a1ae1240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5630a1ae1240] ref P L0: 47.9% 29.2% 10.9% 12.0%
# [libx264 @ 0x5630a1ae1240] ref B L0: 91.3%  6.0%  2.7%
# [libx264 @ 0x5630a1ae1240] ref B L1: 94.4%  5.6%
# [libx264 @ 0x5630a1ae1240] kb/s:1286.28
# videos/softness-movie-esl_max-shear-0.08_id-7ec2f6aca035e69077eab24383a21cb6.mp4
# does not exist, running
# 100%|██████████| 201/201 [10:51<00:00,  3.24s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/7ec2f6aca035e69077eab24383a21cb6/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x564112076240] using SAR=1/1
# [libx264 @ 0x564112076240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x564112076240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x564112076240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-esl_max-shear-0.08_id-7ec2f6aca035e69077eab24383a21cb6.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=150 q=-1.0 Lsize=    4562kB time=00:00:19.80 bitrate=1887.4kbits/s speed=14.8x
# video:4559kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.071338%
# [libx264 @ 0x564112076240] frame I:1     Avg QP:16.77  size:113122
# [libx264 @ 0x564112076240] frame P:51    Avg QP:18.84  size: 57859
# [libx264 @ 0x564112076240] frame B:149   Avg QP:26.45  size: 10761
# [libx264 @ 0x564112076240] consecutive B-frames:  0.5%  2.0%  0.0% 97.5%
# [libx264 @ 0x564112076240] mb I  I16..4: 43.3%  0.0% 56.7%
# [libx264 @ 0x564112076240] mb P  I16..4:  1.0%  0.0%  8.7%  P16..4:  9.1% 14.0% 15.7%  0.0%  0.0%    skip:51.4%
# [libx264 @ 0x564112076240] mb B  I16..4:  0.0%  0.0%  0.3%  B16..8: 20.5% 10.3%  4.7%  direct: 4.7%  skip:59.5%  L0:34.1% L1:33.7% BI:32.2%
# [libx264 @ 0x564112076240] coded y,u,v intra: 81.3% 81.1% 79.2% inter: 24.3% 11.1% 13.5%
# [libx264 @ 0x564112076240] i16 v,h,dc,p: 83% 10%  6%  0%
# [libx264 @ 0x564112076240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 18% 16%  7% 10%  8% 11%  7% 12%
# [libx264 @ 0x564112076240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x564112076240] ref P L0: 44.5% 29.2% 15.5% 10.8%
# [libx264 @ 0x564112076240] ref B L0: 90.5%  7.5%  2.0%
# [libx264 @ 0x564112076240] ref B L1: 94.9%  5.1%
# [libx264 @ 0x564112076240] kb/s:1857.61
# videos/softness-movie-esl_max-shear-0.12_id-7ec2f6aca035e69077eab24383a21cb6.mp4
# does not exist, running
# 100%|██████████| 201/201 [10:53<00:00,  3.25s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/7ec2f6aca035e69077eab24383a21cb6/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55c670c19240] using SAR=1/1
# [libx264 @ 0x55c670c19240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55c670c19240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55c670c19240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-esl_max-shear-0.12_id-7ec2f6aca035e69077eab24383a21cb6.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=136 q=-1.0 Lsize=    6397kB time=00:00:19.80 bitrate=2646.6kbits/s speed=13.4x
# video:6394kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.051351%
# [libx264 @ 0x55c670c19240] frame I:1     Avg QP:17.42  size: 96982
# [libx264 @ 0x55c670c19240] frame P:50    Avg QP:19.48  size: 68947
# [libx264 @ 0x55c670c19240] frame B:150   Avg QP:26.66  size: 20013
# [libx264 @ 0x55c670c19240] consecutive B-frames:  0.5%  0.0%  0.0% 99.5%
# [libx264 @ 0x55c670c19240] mb I  I16..4: 43.3%  0.0% 56.7%
# [libx264 @ 0x55c670c19240] mb P  I16..4:  1.0%  0.0% 17.6%  P16..4:  6.1% 10.5% 13.5%  0.0%  0.0%    skip:51.4%
# [libx264 @ 0x55c670c19240] mb B  I16..4:  0.0%  0.0%  1.4%  B16..8: 17.3% 12.7%  7.1%  direct: 5.1%  skip:56.4%  L0:36.2% L1:33.5% BI:30.4%
# [libx264 @ 0x55c670c19240] coded y,u,v intra: 89.9% 90.0% 87.1% inter: 29.4% 15.7% 17.8%
# [libx264 @ 0x55c670c19240] i16 v,h,dc,p: 85%  9%  6%  0%
# [libx264 @ 0x55c670c19240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11% 18% 16%  8% 10%  8% 11%  7% 12%
# [libx264 @ 0x55c670c19240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55c670c19240] ref P L0: 38.9% 27.5% 19.3% 14.4%
# [libx264 @ 0x55c670c19240] ref B L0: 88.8%  8.3%  2.9%
# [libx264 @ 0x55c670c19240] ref B L1: 95.1%  4.9%
# [libx264 @ 0x55c670c19240] kb/s:2605.52
# cfa1e4c0007fd65d020f809715a6f0b4
# ecce68c50e28a33684826f28780bf6e9
# 1d0fe2ba44a6f635f5504dcbcee0ebc9
# ESL
# videos/softness-movie-esl_max-shear-0.01_id-1d0fe2ba44a6f635f5504dcbcee0ebc9.mp4
# does not exist, running
# 100%|██████████| 201/201 [10:59<00:00,  3.28s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/1d0fe2ba44a6f635f5504dcbcee0ebc9/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5627d671a240] using SAR=1/1
# [libx264 @ 0x5627d671a240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5627d671a240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x5627d671a240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-esl_max-shear-0.01_id-1d0fe2ba44a6f635f5504dcbcee0ebc9.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=0.0 q=-1.0 Lsize=    1672kB time=00:00:19.80 bitrate= 691.9kbits/s speed=  20x
# video:1669kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.192012%
# [libx264 @ 0x5627d671a240] frame I:1     Avg QP:14.34  size:174538
# [libx264 @ 0x5627d671a240] frame P:50    Avg QP:17.34  size: 29109
# [libx264 @ 0x5627d671a240] frame B:150   Avg QP:17.29  size:   524
# [libx264 @ 0x5627d671a240] consecutive B-frames:  0.5%  0.0%  0.0% 99.5%
# [libx264 @ 0x5627d671a240] mb I  I16..4: 43.2%  0.0% 56.8%
# [libx264 @ 0x5627d671a240] mb P  I16..4:  0.7%  0.0%  0.1%  P16..4: 18.4% 13.0% 15.4%  0.0%  0.0%    skip:52.5%
# [libx264 @ 0x5627d671a240] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 17.0%  0.8%  0.2%  direct: 0.4%  skip:81.6%  L0:34.7% L1:48.6% BI:16.7%
# [libx264 @ 0x5627d671a240] coded y,u,v intra: 39.6% 37.7% 37.3% inter: 9.0% 4.7% 4.5%
# [libx264 @ 0x5627d671a240] i16 v,h,dc,p: 87%  8%  5%  0%
# [libx264 @ 0x5627d671a240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 20% 13%  6%  9%  8% 10%  7% 12%
# [libx264 @ 0x5627d671a240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5627d671a240] ref P L0: 56.7% 21.2% 11.2% 10.9%
# [libx264 @ 0x5627d671a240] ref B L0: 73.3% 17.5%  9.2%
# [libx264 @ 0x5627d671a240] ref B L1: 87.4% 12.6%
# [libx264 @ 0x5627d671a240] kb/s:680.04
# videos/softness-movie-esl_max-shear-0.02_id-1d0fe2ba44a6f635f5504dcbcee0ebc9.mp4
# does not exist, running
# 100%|██████████| 201/201 [11:03<00:00,  3.30s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/1d0fe2ba44a6f635f5504dcbcee0ebc9/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x556dbf304240] using SAR=1/1
# [libx264 @ 0x556dbf304240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x556dbf304240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x556dbf304240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-esl_max-shear-0.02_id-1d0fe2ba44a6f635f5504dcbcee0ebc9.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=196 q=-1.0 Lsize=    2053kB time=00:00:19.80 bitrate= 849.3kbits/s speed=19.3x
# video:2050kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.157144%
# [libx264 @ 0x556dbf304240] frame I:1     Avg QP:14.93  size:156854
# [libx264 @ 0x556dbf304240] frame P:50    Avg QP:17.63  size: 35249
# [libx264 @ 0x556dbf304240] frame B:150   Avg QP:24.59  size:  1192
# [libx264 @ 0x556dbf304240] consecutive B-frames:  0.5%  0.0%  0.0% 99.5%
# [libx264 @ 0x556dbf304240] mb I  I16..4: 43.4%  0.0% 56.6%
# [libx264 @ 0x556dbf304240] mb P  I16..4:  0.8%  0.0%  0.3%  P16..4: 16.0% 15.0% 15.9%  0.0%  0.0%    skip:51.9%
# [libx264 @ 0x556dbf304240] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 20.3%  2.3%  0.7%  direct: 1.1%  skip:75.6%  L0:31.9% L1:43.9% BI:24.2%
# [libx264 @ 0x556dbf304240] coded y,u,v intra: 43.0% 41.3% 41.3% inter: 10.8% 5.2% 5.8%
# [libx264 @ 0x556dbf304240] i16 v,h,dc,p: 86%  8%  6%  0%
# [libx264 @ 0x556dbf304240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 19% 14%  7%  9%  8% 10%  7% 12%
# [libx264 @ 0x556dbf304240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x556dbf304240] ref P L0: 53.5% 25.7%  9.0% 11.9%
# [libx264 @ 0x556dbf304240] ref B L0: 81.0% 12.3%  6.7%
# [libx264 @ 0x556dbf304240] ref B L1: 90.0% 10.0%
# [libx264 @ 0x556dbf304240] kb/s:835.04
# videos/softness-movie-esl_max-shear-0.03_id-1d0fe2ba44a6f635f5504dcbcee0ebc9.mp4
# does not exist, running
# 100%|██████████| 201/201 [10:59<00:00,  3.28s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/1d0fe2ba44a6f635f5504dcbcee0ebc9/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x564eb9400240] using SAR=1/1
# [libx264 @ 0x564eb9400240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x564eb9400240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x564eb9400240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-esl_max-shear-0.03_id-1d0fe2ba44a6f635f5504dcbcee0ebc9.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=179 q=-1.0 Lsize=    2483kB time=00:00:19.80 bitrate=1027.5kbits/s speed=17.6x
# video:2480kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.129858%
# [libx264 @ 0x564eb9400240] frame I:1     Avg QP:15.44  size:142333
# [libx264 @ 0x564eb9400240] frame P:51    Avg QP:17.89  size: 40790
# [libx264 @ 0x564eb9400240] frame B:149   Avg QP:25.21  size:  2124
# [libx264 @ 0x564eb9400240] consecutive B-frames:  0.5%  2.0%  0.0% 97.5%
# [libx264 @ 0x564eb9400240] mb I  I16..4: 43.4%  0.0% 56.6%
# [libx264 @ 0x564eb9400240] mb P  I16..4:  1.0%  0.0%  0.8%  P16..4: 14.3% 15.9% 16.5%  0.0%  0.0%    skip:51.5%
# [libx264 @ 0x564eb9400240] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 21.3%  3.8%  1.3%  direct: 2.0%  skip:71.5%  L0:32.2% L1:40.0% BI:27.8%
# [libx264 @ 0x564eb9400240] coded y,u,v intra: 47.0% 45.7% 45.0% inter: 13.5% 6.2% 7.2%
# [libx264 @ 0x564eb9400240] i16 v,h,dc,p: 84% 12%  4%  0%
# [libx264 @ 0x564eb9400240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 18% 15%  7%  9%  8% 10%  7% 11%
# [libx264 @ 0x564eb9400240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x564eb9400240] ref P L0: 51.0% 28.7%  8.8% 11.4%
# [libx264 @ 0x564eb9400240] ref B L0: 87.8%  9.0%  3.2%
# [libx264 @ 0x564eb9400240] ref B L1: 93.1%  6.9%
# [libx264 @ 0x564eb9400240] kb/s:1010.56
# videos/softness-movie-esl_max-shear-0.05_id-1d0fe2ba44a6f635f5504dcbcee0ebc9.mp4
# does not exist, running
# 100%|██████████| 201/201 [11:04<00:00,  3.31s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/1d0fe2ba44a6f635f5504dcbcee0ebc9/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5581b3cc6240] using SAR=1/1
# [libx264 @ 0x5581b3cc6240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5581b3cc6240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x5581b3cc6240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-esl_max-shear-0.05_id-1d0fe2ba44a6f635f5504dcbcee0ebc9.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=167 q=-1.0 Lsize=    3167kB time=00:00:19.80 bitrate=1310.5kbits/s speed=16.4x
# video:3164kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.101907%
# [libx264 @ 0x5581b3cc6240] frame I:1     Avg QP:16.14  size:126004
# [libx264 @ 0x5581b3cc6240] frame P:50    Avg QP:18.38  size: 48356
# [libx264 @ 0x5581b3cc6240] frame B:150   Avg QP:26.27  size:  4638
# [libx264 @ 0x5581b3cc6240] consecutive B-frames:  0.5%  0.0%  0.0% 99.5%
# [libx264 @ 0x5581b3cc6240] mb I  I16..4: 43.3%  0.0% 56.7%
# [libx264 @ 0x5581b3cc6240] mb P  I16..4:  1.0%  0.0%  3.0%  P16..4: 11.9% 15.7% 17.0%  0.0%  0.0%    skip:51.4%
# [libx264 @ 0x5581b3cc6240] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 22.3%  6.7%  2.5%  direct: 3.3%  skip:65.2%  L0:31.2% L1:36.6% BI:32.3%
# [libx264 @ 0x5581b3cc6240] coded y,u,v intra: 65.4% 64.7% 63.8% inter: 17.8% 7.4% 9.4%
# [libx264 @ 0x5581b3cc6240] i16 v,h,dc,p: 84% 10%  6%  0%
# [libx264 @ 0x5581b3cc6240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 18% 16%  7%  9%  8% 11%  7% 11%
# [libx264 @ 0x5581b3cc6240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5581b3cc6240] ref P L0: 47.6% 29.5% 10.4% 12.5%
# [libx264 @ 0x5581b3cc6240] ref B L0: 90.6%  7.0%  2.4%
# [libx264 @ 0x5581b3cc6240] ref B L1: 94.2%  5.8%
# [libx264 @ 0x5581b3cc6240] kb/s:1289.37
# videos/softness-movie-esl_max-shear-0.08_id-1d0fe2ba44a6f635f5504dcbcee0ebc9.mp4
# does not exist, running
# 100%|██████████| 201/201 [11:02<00:00,  3.29s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/1d0fe2ba44a6f635f5504dcbcee0ebc9/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55c20a31a240] using SAR=1/1
# [libx264 @ 0x55c20a31a240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55c20a31a240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55c20a31a240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-esl_max-shear-0.08_id-1d0fe2ba44a6f635f5504dcbcee0ebc9.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=148 q=-1.0 Lsize=    4861kB time=00:00:19.80 bitrate=2011.0kbits/s speed=14.6x
# video:4857kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.066948%
# [libx264 @ 0x55c20a31a240] frame I:1     Avg QP:16.72  size:118146
# [libx264 @ 0x55c20a31a240] frame P:51    Avg QP:19.01  size: 60770
# [libx264 @ 0x55c20a31a240] frame B:149   Avg QP:26.66  size: 11785
# [libx264 @ 0x55c20a31a240] consecutive B-frames:  0.5%  2.0%  0.0% 97.5%
# ...
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55798dff1240] using SAR=1/1
# [libx264 @ 0x55798dff1240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55798dff1240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55798dff1240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-esl_max-shear-0.03_id-a8f2c249ed85533b56b0729b7ab96d18.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=179 q=-1.0 Lsize=    2372kB time=00:00:19.80 bitrate= 981.3kbits/s speed=17.6x
# video:2369kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.135311%
# [libx264 @ 0x55798dff1240] frame I:1     Avg QP:15.27  size:147788
# [libx264 @ 0x55798dff1240] frame P:52    Avg QP:17.92  size: 38884
# [libx264 @ 0x55798dff1240] frame B:148   Avg QP:25.39  size:  1723
# [libx264 @ 0x55798dff1240] consecutive B-frames:  0.5%  3.0%  3.0% 93.5%
# [libx264 @ 0x55798dff1240] mb I  I16..4: 43.4%  0.0% 56.6%
# [libx264 @ 0x55798dff1240] mb P  I16..4:  0.9%  0.0%  0.5%  P16..4: 14.8% 15.5% 16.0%  0.0%  0.0%    skip:52.3%
# [libx264 @ 0x55798dff1240] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 21.5%  3.1%  1.0%  direct: 1.6%  skip:72.7%  L0:28.8% L1:41.8% BI:29.4%
# [libx264 @ 0x55798dff1240] coded y,u,v intra: 45.4% 43.8% 43.6% inter: 12.5% 6.0% 6.9%
# [libx264 @ 0x55798dff1240] i16 v,h,dc,p: 84% 11%  4%  0%
# [libx264 @ 0x55798dff1240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 18% 13%  7%  9%  8% 10%  7% 12%
# [libx264 @ 0x55798dff1240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55798dff1240] ref P L0: 55.3% 29.3%  8.3%  7.1%
# [libx264 @ 0x55798dff1240] ref B L0: 88.9%  8.8%  2.3%
# [libx264 @ 0x55798dff1240] ref B L1: 92.8%  7.2%
# [libx264 @ 0x55798dff1240] kb/s:965.11
# videos/softness-movie-esl_max-shear-0.05_id-a8f2c249ed85533b56b0729b7ab96d18.mp4
# does not exist, running
# 100%|██████████| 201/201 [11:17<00:00,  3.37s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/a8f2c249ed85533b56b0729b7ab96d18/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55c5a52d3240] using SAR=1/1
# [libx264 @ 0x55c5a52d3240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55c5a52d3240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55c5a52d3240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-esl_max-shear-0.05_id-a8f2c249ed85533b56b0729b7ab96d18.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=168 q=-1.0 Lsize=    3201kB time=00:00:19.80 bitrate=1324.4kbits/s speed=16.6x
# video:3198kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.100713%
# [libx264 @ 0x55c5a52d3240] frame I:1     Avg QP:15.97  size:131227
# [libx264 @ 0x55c5a52d3240] frame P:51    Avg QP:18.55  size: 48323
# [libx264 @ 0x55c5a52d3240] frame B:149   Avg QP:26.11  size:  4552
# [libx264 @ 0x55c5a52d3240] consecutive B-frames:  0.5%  1.0%  3.0% 95.5%
# [libx264 @ 0x55c5a52d3240] mb I  I16..4: 43.2%  0.0% 56.8%
# [libx264 @ 0x55c5a52d3240] mb P  I16..4:  0.9%  0.0%  2.4%  P16..4: 12.4% 16.1% 16.6%  0.0%  0.0%    skip:51.6%
# [libx264 @ 0x55c5a52d3240] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 22.0%  6.3%  2.5%  direct: 3.6%  skip:65.5%  L0:30.4% L1:36.1% BI:33.6%
# [libx264 @ 0x55c5a52d3240] coded y,u,v intra: 62.1% 61.6% 60.2% inter: 18.1% 7.6% 9.7%
# [libx264 @ 0x55c5a52d3240] i16 v,h,dc,p: 82% 12%  6%  0%
# [libx264 @ 0x55c5a52d3240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 19% 16%  7%  9%  8% 10%  7% 11%
# [libx264 @ 0x55c5a52d3240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55c5a52d3240] ref P L0: 48.4% 29.9% 11.4% 10.4%
# [libx264 @ 0x55c5a52d3240] ref B L0: 90.5%  7.7%  1.8%
# [libx264 @ 0x55c5a52d3240] ref B L1: 95.1%  4.9%
# [libx264 @ 0x55c5a52d3240] kb/s:1303.08
# videos/softness-movie-esl_max-shear-0.08_id-a8f2c249ed85533b56b0729b7ab96d18.mp4
# does not exist, running
# 100%|██████████| 201/201 [11:20<00:00,  3.38s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/a8f2c249ed85533b56b0729b7ab96d18/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55733f64d240] using SAR=1/1
# [libx264 @ 0x55733f64d240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55733f64d240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55733f64d240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-esl_max-shear-0.08_id-a8f2c249ed85533b56b0729b7ab96d18.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=147 q=-1.0 Lsize=    4865kB time=00:00:19.80 bitrate=2012.9kbits/s speed=14.4x
# video:4862kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.066887%
# [libx264 @ 0x55733f64d240] frame I:1     Avg QP:16.93  size:111543
# [libx264 @ 0x55733f64d240] frame P:51    Avg QP:18.98  size: 60340
# [libx264 @ 0x55733f64d240] frame B:149   Avg QP:26.47  size: 12007
# [libx264 @ 0x55733f64d240] consecutive B-frames:  0.5%  2.0%  0.0% 97.5%
# [libx264 @ 0x55733f64d240] mb I  I16..4: 43.2%  0.0% 56.8%
# [libx264 @ 0x55733f64d240] mb P  I16..4:  1.0%  0.0%  9.6%  P16..4:  8.7% 13.4% 15.9%  0.0%  0.0%    skip:51.4%
# [libx264 @ 0x55733f64d240] mb B  I16..4:  0.0%  0.0%  0.3%  B16..8: 19.5% 10.7%  5.2%  direct: 5.0%  skip:59.3%  L0:33.7% L1:34.0% BI:32.4%
# [libx264 @ 0x55733f64d240] coded y,u,v intra: 82.9% 82.9% 80.5% inter: 25.5% 11.7% 14.4%
# [libx264 @ 0x55733f64d240] i16 v,h,dc,p: 85%  9%  6%  0%
# [libx264 @ 0x55733f64d240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 18% 16%  7% 10%  8% 11%  7% 12%
# [libx264 @ 0x55733f64d240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55733f64d240] ref P L0: 43.2% 28.6% 16.0% 12.2%
# [libx264 @ 0x55733f64d240] ref B L0: 90.5%  7.3%  2.2%
# [libx264 @ 0x55733f64d240] ref B L1: 95.2%  4.8%
# [libx264 @ 0x55733f64d240] kb/s:1981.23
# videos/softness-movie-esl_max-shear-0.12_id-a8f2c249ed85533b56b0729b7ab96d18.mp4
# does not exist, running
# 100%|██████████| 201/201 [11:17<00:00,  3.37s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/a8f2c249ed85533b56b0729b7ab96d18/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x560e4d63e240] using SAR=1/1
# [libx264 @ 0x560e4d63e240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x560e4d63e240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x560e4d63e240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-esl_max-shear-0.12_id-a8f2c249ed85533b56b0729b7ab96d18.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=133 q=-1.0 Lsize=    6428kB time=00:00:19.80 bitrate=2659.7kbits/s speed=13.1x
# video:6425kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.051099%
# [libx264 @ 0x560e4d63e240] frame I:1     Avg QP:17.38  size:101272
# [libx264 @ 0x560e4d63e240] frame P:50    Avg QP:19.35  size: 68937
# [libx264 @ 0x560e4d63e240] frame B:150   Avg QP:26.53  size: 20204
# [libx264 @ 0x560e4d63e240] consecutive B-frames:  0.5%  0.0%  0.0% 99.5%
# [libx264 @ 0x560e4d63e240] mb I  I16..4: 43.3%  0.0% 56.7%
# [libx264 @ 0x560e4d63e240] mb P  I16..4:  1.1%  0.0% 17.6%  P16..4:  6.0% 10.2% 13.7%  0.0%  0.0%    skip:51.4%
# [libx264 @ 0x560e4d63e240] mb B  I16..4:  0.0%  0.0%  1.4%  B16..8: 17.2% 12.9%  7.4%  direct: 5.0%  skip:56.2%  L0:35.4% L1:33.8% BI:30.8%
# [libx264 @ 0x560e4d63e240] coded y,u,v intra: 89.6% 89.8% 87.1% inter: 29.6% 15.6% 17.9%
# [libx264 @ 0x560e4d63e240] i16 v,h,dc,p: 83% 11%  6%  0%
# [libx264 @ 0x560e4d63e240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 17% 16%  8% 10%  8% 11%  7% 12%
# [libx264 @ 0x560e4d63e240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x560e4d63e240] ref P L0: 40.0% 27.5% 19.0% 13.5%
# [libx264 @ 0x560e4d63e240] ref B L0: 88.9%  8.1%  3.0%
# [libx264 @ 0x560e4d63e240] ref B L1: 95.3%  4.7%
# [libx264 @ 0x560e4d63e240] kb/s:2618.41

# %%
output = defaultdict(list)

for job in project:
    print(job)
    prep = job.sp["prep"]
    if prep == "ESL":
        continue
    print(prep)
    
    experiments = sorted(glob.glob(job.fn("aqs_therm_experiments/*/*/traj-fire_period-*.gsd")))
    if len(experiments) == 0:
        continue
    for exper in experiments:
        max_shear = utils.extract_between(exper, "max-shear-", "/")
        period = utils.extract_between(exper, "period-", ".gsd")
        temp = utils.extract_between(exper, "temp-", "/")
        df_path = f"aqs_therm_experiments/max-shear-{max_shear}/temp-{temp}/final-cycles-softness_period-{period}.parquet"
        new_df_path = f"aqs_therm_experiments/max-shear-{max_shear}/temp-{temp}/ave-softness-fft-abs_period-{period}.parquet"
        sp = Statepoint(max_shear=float(max_shear), period=float(period), temp=float(temp), prep=prep)
        
        if float(period) != 1000.0 or float(temp) > 5e-3:
            continue

        if job.isfile(df_path):
            dataset = pl.read_parquet(job.fn(df_path), use_pyarrow=True)
        else:
            continue
        
        traj = gsd.hoomd.open(exper)
        
        # softs = np.stack(dataset["soft"].to_numpy())
        # nsofts = softs.reshape(5, 40, 32768)
        # nsofts = nsofts.mean(axis=0)

        # compute fft
        # soft_ffts = np.fft.fft(nsofts.T, axis=-1)

        output_file = f"videos/softness-movie-htl_max-shear-{max_shear}_id-{job.id}.mp4"

        if os.path.exists(output_file):
            continue

        # output[sp].append(soft_ffts)
        fig, ax = plt.subplots()
        frame_path = job.fn("videos/softness-movie/")
        if os.path.exists(frame_path):
            shutil.rmtree(frame_path)
        os.makedirs(job.fn("videos/softness-movie/"), exist_ok=True)
        # i = 0
        for frame, _, soft in tqdm(dataset.rows()):
            # print(frame)
            # if i == 2:
            #     break
            snap = traj[frame]
            name = job.fn("videos/softness-movie/softness-movie-{:04d}.png".format(frame))
            if os.path.exists(name):
                continue

            plot_data(snap, soft, ax=ax, lim=40)
            plt.savefig(name, dpi=150)
            # clear axis
            ax.cla()

        import ffmpeg
        (
        ffmpeg
            .input(job.fn("videos/softness-movie/softness-movie-*.png"), pattern_type="glob", framerate=10)
            .output(output_file).run()
        )
        # break
    # break
# Out:
# 634e14bc75836df75158fb15f379d8bb
# HTL
# 100%|██████████| 201/201 [11:09<00:00,  3.33s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/634e14bc75836df75158fb15f379d8bb/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x564ae2671240] using SAR=1/1
# [libx264 @ 0x564ae2671240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x564ae2671240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x564ae2671240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-htl_max-shear-0.01_id-634e14bc75836df75158fb15f379d8bb.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=0.0 q=-1.0 Lsize=    1709kB time=00:00:19.80 bitrate= 707.1kbits/s speed=20.1x
# video:1706kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.187898%
# [libx264 @ 0x564ae2671240] frame I:1     Avg QP:14.40  size:174177
# [libx264 @ 0x564ae2671240] frame P:51    Avg QP:17.57  size: 29113
# [libx264 @ 0x564ae2671240] frame B:149   Avg QP:21.27  size:   585
# [libx264 @ 0x564ae2671240] consecutive B-frames:  0.5%  2.0%  0.0% 97.5%
# [libx264 @ 0x564ae2671240] mb I  I16..4: 43.4%  0.0% 56.6%
# [libx264 @ 0x564ae2671240] mb P  I16..4:  0.6%  0.0%  0.0%  P16..4: 18.7% 12.2% 14.5%  0.0%  0.0%    skip:53.9%
# [libx264 @ 0x564ae2671240] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 17.0%  0.8%  0.3%  direct: 0.5%  skip:81.4%  L0:30.5% L1:52.1% BI:17.4%
# [libx264 @ 0x564ae2671240] coded y,u,v intra: 40.1% 37.7% 37.6% inter: 9.1% 4.6% 4.2%
# [libx264 @ 0x564ae2671240] i16 v,h,dc,p: 86%  8%  6%  0%
# [libx264 @ 0x564ae2671240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 20% 13%  7%  9%  7% 10%  7% 11%
# [libx264 @ 0x564ae2671240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x564ae2671240] ref P L0: 61.9% 20.3% 10.6%  7.3%
# [libx264 @ 0x564ae2671240] ref B L0: 78.0% 15.8%  6.1%
# [libx264 @ 0x564ae2671240] ref B L1: 87.8% 12.2%
# [libx264 @ 0x564ae2671240] kb/s:694.93
# 100%|██████████| 201/201 [11:01<00:00,  3.29s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/634e14bc75836df75158fb15f379d8bb/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x56065c096240] using SAR=1/1
# [libx264 @ 0x56065c096240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x56065c096240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x56065c096240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-htl_max-shear-0.02_id-634e14bc75836df75158fb15f379d8bb.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=192 q=-1.0 Lsize=    2129kB time=00:00:19.80 bitrate= 880.7kbits/s speed=18.9x
# video:2125kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.151529%
# [libx264 @ 0x56065c096240] frame I:1     Avg QP:14.86  size:160104
# [libx264 @ 0x56065c096240] frame P:50    Avg QP:17.72  size: 36164
# [libx264 @ 0x56065c096240] frame B:150   Avg QP:25.22  size:  1383
# [libx264 @ 0x56065c096240] consecutive B-frames:  0.5%  0.0%  0.0% 99.5%
# [libx264 @ 0x56065c096240] mb I  I16..4: 43.5%  0.0% 56.5%
# [libx264 @ 0x56065c096240] mb P  I16..4:  0.8%  0.0%  0.5%  P16..4: 16.1% 14.2% 15.2%  0.0%  0.0%    skip:53.2%
# [libx264 @ 0x56065c096240] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 20.7%  2.5%  0.9%  direct: 1.3%  skip:74.5%  L0:31.8% L1:44.0% BI:24.2%
# [libx264 @ 0x56065c096240] coded y,u,v intra: 45.3% 44.0% 43.6% inter: 10.9% 5.3% 5.4%
# [libx264 @ 0x56065c096240] i16 v,h,dc,p: 84% 10%  5%  0%
# [libx264 @ 0x56065c096240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 18% 13%  7%  9%  8% 10%  7% 12%
# [libx264 @ 0x56065c096240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x56065c096240] ref P L0: 58.2% 25.4%  9.5%  6.9%
# [libx264 @ 0x56065c096240] ref B L0: 83.9% 12.9%  3.2%
# [libx264 @ 0x56065c096240] ref B L1: 88.4% 11.6%
# [libx264 @ 0x56065c096240] kb/s:865.99
# 100%|██████████| 201/201 [11:03<00:00,  3.30s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/634e14bc75836df75158fb15f379d8bb/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x560d571b7240] using SAR=1/1
# [libx264 @ 0x560d571b7240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x560d571b7240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x560d571b7240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-htl_max-shear-0.03_id-634e14bc75836df75158fb15f379d8bb.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=176 q=-1.0 Lsize=    2590kB time=00:00:19.80 bitrate=1071.8kbits/s speed=17.3x
# video:2587kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.124484%
# [libx264 @ 0x560d571b7240] frame I:1     Avg QP:15.35  size:146889
# [libx264 @ 0x560d571b7240] frame P:52    Avg QP:17.90  size: 41407
# [libx264 @ 0x560d571b7240] frame B:148   Avg QP:26.32  size:  2355
# [libx264 @ 0x560d571b7240] consecutive B-frames:  0.5%  4.0%  0.0% 95.5%
# [libx264 @ 0x560d571b7240] mb I  I16..4: 43.3%  0.0% 56.7%
# [libx264 @ 0x560d571b7240] mb P  I16..4:  0.9%  0.0%  1.1%  P16..4: 14.4% 15.6% 16.3%  0.0%  0.0%    skip:51.7%
# [libx264 @ 0x560d571b7240] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 21.4%  4.1%  1.5%  direct: 2.2%  skip:70.8%  L0:29.3% L1:42.2% BI:28.4%
# [libx264 @ 0x560d571b7240] coded y,u,v intra: 52.1% 50.9% 50.7% inter: 13.4% 6.3% 6.8%
# [libx264 @ 0x560d571b7240] i16 v,h,dc,p: 85%  9%  5%  0%
# [libx264 @ 0x560d571b7240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14% 18% 14%  7% 10%  8% 11%  7% 12%
# [libx264 @ 0x560d571b7240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x560d571b7240] ref P L0: 53.4% 27.2% 10.2%  9.2%
# [libx264 @ 0x560d571b7240] ref B L0: 87.4% 10.5%  2.0%
# [libx264 @ 0x560d571b7240] ref B L1: 92.2%  7.8%
# [libx264 @ 0x560d571b7240] kb/s:1054.19
# 100%|██████████| 201/201 [11:06<00:00,  3.32s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/634e14bc75836df75158fb15f379d8bb/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5626aba77240] using SAR=1/1
# [libx264 @ 0x5626aba77240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5626aba77240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x5626aba77240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-htl_max-shear-0.05_id-634e14bc75836df75158fb15f379d8bb.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=156 q=-1.0 Lsize=    3468kB time=00:00:19.80 bitrate=1434.8kbits/s speed=15.3x
# video:3465kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.093411%
# [libx264 @ 0x5626aba77240] frame I:1     Avg QP:16.14  size:126401
# [libx264 @ 0x5626aba77240] frame P:51    Avg QP:18.35  size: 50626
# [libx264 @ 0x5626aba77240] frame B:149   Avg QP:26.54  size:  5629
# [libx264 @ 0x5626aba77240] consecutive B-frames:  0.5%  2.0%  0.0% 97.5%
# [libx264 @ 0x5626aba77240] mb I  I16..4: 43.2%  0.0% 56.8%
# [libx264 @ 0x5626aba77240] mb P  I16..4:  1.0%  0.0%  3.7%  P16..4: 11.8% 15.6% 16.3%  0.0%  0.0%    skip:51.6%
# [libx264 @ 0x5626aba77240] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 21.8%  7.3%  3.0%  direct: 3.7%  skip:64.2%  L0:30.9% L1:36.3% BI:32.8%
# [libx264 @ 0x5626aba77240] coded y,u,v intra: 69.8% 69.3% 68.2% inter: 18.7% 8.4% 9.7%
# [libx264 @ 0x5626aba77240] i16 v,h,dc,p: 84% 11%  5%  0%
# [libx264 @ 0x5626aba77240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 18% 15%  7% 10%  8% 11%  7% 12%
# [libx264 @ 0x5626aba77240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5626aba77240] ref P L0: 49.4% 29.4% 11.3% 10.0%
# [libx264 @ 0x5626aba77240] ref B L0: 90.4%  7.7%  1.8%
# [libx264 @ 0x5626aba77240] ref B L1: 93.9%  6.1%
# [libx264 @ 0x5626aba77240] kb/s:1411.77
# 100%|██████████| 201/201 [11:03<00:00,  3.30s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/634e14bc75836df75158fb15f379d8bb/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x559019399240] using SAR=1/1
# [libx264 @ 0x559019399240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x559019399240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x559019399240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-htl_max-shear-0.08_id-634e14bc75836df75158fb15f379d8bb.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=146 q=-1.0 Lsize=    4901kB time=00:00:19.80 bitrate=2027.7kbits/s speed=14.4x
# video:4898kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.066159%
# [libx264 @ 0x559019399240] frame I:1     Avg QP:16.87  size:114793
# [libx264 @ 0x559019399240] frame P:50    Avg QP:19.02  size: 61441
# [libx264 @ 0x559019399240] frame B:150   Avg QP:26.53  size: 12184
# [libx264 @ 0x559019399240] consecutive B-frames:  0.5%  0.0%  0.0% 99.5%
# [libx264 @ 0x559019399240] mb I  I16..4: 43.2%  0.0% 56.8%
# [libx264 @ 0x559019399240] mb P  I16..4:  1.0%  0.0%  9.2%  P16..4:  8.6% 13.4% 16.2%  0.0%  0.0%    skip:51.6%
# [libx264 @ 0x559019399240] mb B  I16..4:  0.0%  0.0%  0.3%  B16..8: 19.7% 10.7%  5.2%  direct: 4.9%  skip:59.2%  L0:31.9% L1:35.3% BI:32.7%
# [libx264 @ 0x559019399240] coded y,u,v intra: 82.2% 82.0% 79.9% inter: 25.4% 11.8% 13.8%
# [libx264 @ 0x559019399240] i16 v,h,dc,p: 84% 11%  6%  0%
# [libx264 @ 0x559019399240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 18% 16%  7% 10%  8% 11%  7% 12%
# [libx264 @ 0x559019399240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x559019399240] ref P L0: 43.2% 29.0% 15.4% 12.3%
# [libx264 @ 0x559019399240] ref B L0: 89.9%  7.5%  2.6%
# [libx264 @ 0x559019399240] ref B L1: 94.5%  5.5%
# [libx264 @ 0x559019399240] kb/s:1995.82
# 100%|██████████| 201/201 [11:04<00:00,  3.31s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/634e14bc75836df75158fb15f379d8bb/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55ae1b3f5240] using SAR=1/1
# [libx264 @ 0x55ae1b3f5240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55ae1b3f5240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55ae1b3f5240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-htl_max-shear-0.12_id-634e14bc75836df75158fb15f379d8bb.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=135 q=-1.0 Lsize=    6283kB time=00:00:19.80 bitrate=2599.5kbits/s speed=13.3x
# video:6280kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.052095%
# [libx264 @ 0x55ae1b3f5240] frame I:1     Avg QP:17.18  size:110356
# [libx264 @ 0x55ae1b3f5240] frame P:50    Avg QP:19.52  size: 68817
# [libx264 @ 0x55ae1b3f5240] frame B:150   Avg QP:26.81  size: 19191
# [libx264 @ 0x55ae1b3f5240] consecutive B-frames:  0.5%  0.0%  0.0% 99.5%
# [libx264 @ 0x55ae1b3f5240] mb I  I16..4: 43.1%  0.0% 56.9%
# [libx264 @ 0x55ae1b3f5240] mb P  I16..4:  0.9%  0.0% 15.4%  P16..4:  6.3% 10.7% 15.0%  0.0%  0.0%    skip:51.6%
# [libx264 @ 0x55ae1b3f5240] mb B  I16..4:  0.0%  0.0%  1.1%  B16..8: 17.4% 12.7%  7.1%  direct: 5.1%  skip:56.6%  L0:33.9% L1:34.2% BI:31.9%
# [libx264 @ 0x55ae1b3f5240] coded y,u,v intra: 89.2% 89.2% 86.6% inter: 29.5% 14.9% 17.2%
# [libx264 @ 0x55ae1b3f5240] i16 v,h,dc,p: 87%  8%  5%  0%
# [libx264 @ 0x55ae1b3f5240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 18% 16%  7% 10%  8% 11%  7% 12%
# [libx264 @ 0x55ae1b3f5240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55ae1b3f5240] ref P L0: 40.6% 27.7% 18.7% 12.9%
# [libx264 @ 0x55ae1b3f5240] ref B L0: 88.7%  8.5%  2.8%
# [libx264 @ 0x55ae1b3f5240] ref B L1: 94.8%  5.2%
# [libx264 @ 0x55ae1b3f5240] kb/s:2559.16
# 7ec2f6aca035e69077eab24383a21cb6
# cfa1e4c0007fd65d020f809715a6f0b4
# HTL
# 100%|██████████| 201/201 [11:02<00:00,  3.30s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/cfa1e4c0007fd65d020f809715a6f0b4/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55d7546c2240] using SAR=1/1
# [libx264 @ 0x55d7546c2240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55d7546c2240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55d7546c2240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-htl_max-shear-0.01_id-cfa1e4c0007fd65d020f809715a6f0b4.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=198 q=-1.0 Lsize=    1755kB time=00:00:19.80 bitrate= 726.1kbits/s speed=19.5x
# video:1752kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.182951%
# [libx264 @ 0x55d7546c2240] frame I:1     Avg QP:14.35  size:176021
# [libx264 @ 0x55d7546c2240] frame P:51    Avg QP:17.38  size: 29905
# [libx264 @ 0x55d7546c2240] frame B:149   Avg QP:22.01  size:   618
# [libx264 @ 0x55d7546c2240] consecutive B-frames:  0.5%  2.0%  0.0% 97.5%
# [libx264 @ 0x55d7546c2240] mb I  I16..4: 43.3%  0.0% 56.7%
# [libx264 @ 0x55d7546c2240] mb P  I16..4:  0.6%  0.0%  0.0%  P16..4: 18.3% 12.9% 15.1%  0.0%  0.0%    skip:53.1%
# [libx264 @ 0x55d7546c2240] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 17.2%  0.9%  0.3%  direct: 0.5%  skip:81.0%  L0:31.2% L1:49.8% BI:19.0%
# [libx264 @ 0x55d7546c2240] coded y,u,v intra: 39.3% 37.1% 37.6% inter: 9.5% 4.7% 4.4%
# [libx264 @ 0x55d7546c2240] i16 v,h,dc,p: 87%  8%  5%  0%
# [libx264 @ 0x55d7546c2240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17% 20% 13%  6%  9%  8% 10%  7% 11%
# [libx264 @ 0x55d7546c2240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55d7546c2240] ref P L0: 60.8% 20.5% 11.7%  7.1%
# [libx264 @ 0x55d7546c2240] ref B L0: 79.1% 15.8%  5.1%
# [libx264 @ 0x55d7546c2240] ref B L1: 87.0% 13.0%
# [libx264 @ 0x55d7546c2240] kb/s:713.73
# 100%|██████████| 201/201 [11:03<00:00,  3.30s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/cfa1e4c0007fd65d020f809715a6f0b4/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55aeb0c8d240] using SAR=1/1
# [libx264 @ 0x55aeb0c8d240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55aeb0c8d240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55aeb0c8d240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-htl_max-shear-0.02_id-cfa1e4c0007fd65d020f809715a6f0b4.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=189 q=-1.0 Lsize=    2273kB time=00:00:19.80 bitrate= 940.6kbits/s speed=18.6x
# video:2270kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.141177%
# [libx264 @ 0x55aeb0c8d240] frame I:1     Avg QP:15.06  size:155168
# [libx264 @ 0x55aeb0c8d240] frame P:51    Avg QP:17.74  size: 38300
# [libx264 @ 0x55aeb0c8d240] frame B:149   Avg QP:25.41  size:  1447
# [libx264 @ 0x55aeb0c8d240] consecutive B-frames:  0.5%  1.0%  3.0% 95.5%
# [libx264 @ 0x55aeb0c8d240] mb I  I16..4: 43.3%  0.0% 56.7%
# [libx264 @ 0x55aeb0c8d240] mb P  I16..4:  0.8%  0.0%  0.4%  P16..4: 15.8% 14.7% 15.5%  0.0%  0.0%    skip:52.7%
# [libx264 @ 0x55aeb0c8d240] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 20.4%  2.6%  1.0%  direct: 1.5%  skip:74.5%  L0:29.3% L1:43.7% BI:27.0%
# [libx264 @ 0x55aeb0c8d240] coded y,u,v intra: 44.2% 43.0% 42.7% inter: 11.5% 5.7% 6.0%
# [libx264 @ 0x55aeb0c8d240] i16 v,h,dc,p: 87%  8%  4%  0%
# [libx264 @ 0x55aeb0c8d240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 19% 13%  7%  9%  8% 11%  7% 12%
# [libx264 @ 0x55aeb0c8d240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55aeb0c8d240] ref P L0: 56.8% 26.3%  9.2%  7.7%
# [libx264 @ 0x55aeb0c8d240] ref B L0: 86.6% 10.3%  3.1%
# [libx264 @ 0x55aeb0c8d240] ref B L1: 91.7%  8.3%
# [libx264 @ 0x55aeb0c8d240] kb/s:925.00
# 100%|██████████| 201/201 [11:04<00:00,  3.31s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/cfa1e4c0007fd65d020f809715a6f0b4/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5614326b8240] using SAR=1/1
# [libx264 @ 0x5614326b8240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5614326b8240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x5614326b8240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-htl_max-shear-0.03_id-cfa1e4c0007fd65d020f809715a6f0b4.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=176 q=-1.0 Lsize=    2616kB time=00:00:19.80 bitrate=1082.5kbits/s speed=17.3x
# video:2613kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.122648%
# [libx264 @ 0x5614326b8240] frame I:1     Avg QP:15.40  size:145157
# [libx264 @ 0x5614326b8240] frame P:52    Avg QP:18.12  size: 41727
# [libx264 @ 0x5614326b8240] frame B:148   Avg QP:26.00  size:  2434
# [libx264 @ 0x5614326b8240] consecutive B-frames:  0.5%  3.0%  3.0% 93.5%
# [libx264 @ 0x5614326b8240] mb I  I16..4: 43.4%  0.0% 56.6%
# [libx264 @ 0x5614326b8240] mb P  I16..4:  0.9%  0.0%  1.1%  P16..4: 14.2% 15.7% 16.1%  0.0%  0.0%    skip:52.0%
# [libx264 @ 0x5614326b8240] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 21.3%  4.2%  1.5%  direct: 2.1%  skip:70.8%  L0:32.4% L1:38.4% BI:29.1%
# [libx264 @ 0x5614326b8240] coded y,u,v intra: 53.3% 52.3% 51.7% inter: 13.5% 6.4% 6.9%
# [libx264 @ 0x5614326b8240] i16 v,h,dc,p: 83% 12%  5%  0%
# [libx264 @ 0x5614326b8240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14% 18% 14%  7% 10%  8% 11%  7% 12%
# [libx264 @ 0x5614326b8240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5614326b8240] ref P L0: 54.5% 27.1%  9.9%  8.5%
# [libx264 @ 0x5614326b8240] ref B L0: 86.8% 10.2%  3.0%
# [libx264 @ 0x5614326b8240] ref B L1: 92.5%  7.5%
# [libx264 @ 0x5614326b8240] kb/s:1064.79
# 100%|██████████| 201/201 [11:12<00:00,  3.34s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/cfa1e4c0007fd65d020f809715a6f0b4/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55e84759d240] using SAR=1/1
# [libx264 @ 0x55e84759d240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55e84759d240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55e84759d240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-htl_max-shear-0.05_id-cfa1e4c0007fd65d020f809715a6f0b4.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=158 q=-1.0 Lsize=    3505kB time=00:00:19.80 bitrate=1450.1kbits/s speed=15.6x
# video:3502kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.091974%
# [libx264 @ 0x55e84759d240] frame I:1     Avg QP:16.13  size:125478
# [libx264 @ 0x55e84759d240] frame P:52    Avg QP:18.57  size: 50210
# [libx264 @ 0x55e84759d240] frame B:148   Avg QP:26.42  size:  5734
# [libx264 @ 0x55e84759d240] consecutive B-frames:  0.5%  3.0%  3.0% 93.5%
# [libx264 @ 0x55e84759d240] mb I  I16..4: 43.1%  0.0% 56.9%
# [libx264 @ 0x55e84759d240] mb P  I16..4:  1.0%  0.0%  3.7%  P16..4: 11.3% 16.0% 16.4%  0.0%  0.0%    skip:51.6%
# [libx264 @ 0x55e84759d240] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 21.7%  7.4%  3.1%  direct: 3.8%  skip:64.0%  L0:30.3% L1:37.5% BI:32.2%
# [libx264 @ 0x55e84759d240] coded y,u,v intra: 69.6% 68.9% 67.5% inter: 19.2% 8.7% 10.1%
# [libx264 @ 0x55e84759d240] i16 v,h,dc,p: 85% 10%  5%  0%
# [libx264 @ 0x55e84759d240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 19% 15%  7% 10%  8% 11%  7% 11%
# [libx264 @ 0x55e84759d240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55e84759d240] ref P L0: 49.0% 29.0% 12.1%  9.9%
# [libx264 @ 0x55e84759d240] ref B L0: 91.2%  7.3%  1.5%
# [libx264 @ 0x55e84759d240] ref B L1: 94.4%  5.6%
# [libx264 @ 0x55e84759d240] kb/s:1426.92
# 100%|██████████| 201/201 [11:08<00:00,  3.32s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/cfa1e4c0007fd65d020f809715a6f0b4/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5635654f2240] using SAR=1/1
# [libx264 @ 0x5635654f2240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5635654f2240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x5635654f2240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-htl_max-shear-0.08_id-cfa1e4c0007fd65d020f809715a6f0b4.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=140 q=-1.0 Lsize=    5464kB time=00:00:19.80 bitrate=2260.8kbits/s speed=13.8x
# video:5461kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.059834%
# [libx264 @ 0x5635654f2240] frame I:1     Avg QP:17.10  size:107390
# [libx264 @ 0x5635654f2240] frame P:51    Avg QP:19.18  size: 62719
# [libx264 @ 0x5635654f2240] frame B:149   Avg QP:26.68  size: 15338
# [libx264 @ 0x5635654f2240] consecutive B-frames:  0.5%  2.0%  0.0% 97.5%
# [libx264 @ 0x5635654f2240] mb I  I16..4: 43.1%  0.0% 56.9%
# [libx264 @ 0x5635654f2240] mb P  I16..4:  1.0%  0.0% 12.4%  P16..4:  8.1% 12.4% 14.7%  0.0%  0.0%    skip:51.4%
# [libx264 @ 0x5635654f2240] mb B  I16..4:  0.0%  0.0%  0.8%  B16..8: 18.5% 11.2%  6.0%  direct: 5.2%  skip:58.3%  L0:33.7% L1:35.0% BI:31.3%
# [libx264 @ 0x5635654f2240] coded y,u,v intra: 87.1% 87.1% 84.6% inter: 26.9% 13.5% 15.6%
# [libx264 @ 0x5635654f2240] i16 v,h,dc,p: 85%  9%  5%  0%
# [libx264 @ 0x5635654f2240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 17% 16%  8% 10%  8% 11%  7% 12%
# [libx264 @ 0x5635654f2240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5635654f2240] ref P L0: 42.2% 27.8% 17.6% 12.3%
# [libx264 @ 0x5635654f2240] ref B L0: 90.0%  7.4%  2.6%
# [libx264 @ 0x5635654f2240] ref B L1: 94.9%  5.1%
# [libx264 @ 0x5635654f2240] kb/s:2225.44
# 100%|██████████| 201/201 [11:10<00:00,  3.33s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
# ...
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55629d021240] using SAR=1/1
# [libx264 @ 0x55629d021240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55629d021240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55629d021240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-htl_max-shear-0.03_id-9158e73b2e4c9fd1a565e1e5d1bc3af5.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=180 q=-1.0 Lsize=    2585kB time=00:00:19.80 bitrate=1069.5kbits/s speed=17.7x
# video:2582kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.123838%
# [libx264 @ 0x55629d021240] frame I:1     Avg QP:15.44  size:145082
# [libx264 @ 0x55629d021240] frame P:53    Avg QP:18.05  size: 41537
# [libx264 @ 0x55629d021240] frame B:147   Avg QP:25.97  size:  2017
# [libx264 @ 0x55629d021240] consecutive B-frames:  1.0%  3.0%  4.5% 91.5%
# [libx264 @ 0x55629d021240] mb I  I16..4: 43.2%  0.0% 56.8%
# [libx264 @ 0x55629d021240] mb P  I16..4:  0.9%  0.0%  0.8%  P16..4: 14.5% 15.8% 16.0%  0.0%  0.0%    skip:52.0%
# [libx264 @ 0x55629d021240] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 21.6%  3.7%  1.3%  direct: 1.9%  skip:71.5%  L0:27.9% L1:41.6% BI:30.5%
# [libx264 @ 0x55629d021240] coded y,u,v intra: 48.5% 47.6% 47.6% inter: 13.3% 6.4% 7.0%
# [libx264 @ 0x55629d021240] i16 v,h,dc,p: 85%  9%  6%  0%
# [libx264 @ 0x55629d021240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 20% 14%  7%  9%  8% 10%  6% 11%
# [libx264 @ 0x55629d021240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55629d021240] ref P L0: 55.5% 27.6%  7.7%  9.2%
# [libx264 @ 0x55629d021240] ref B L0: 88.8%  7.9%  3.3%
# [libx264 @ 0x55629d021240] ref B L1: 92.4%  7.6%
# [libx264 @ 0x55629d021240] kb/s:1051.98
# 100%|██████████| 201/201 [11:25<00:00,  3.41s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/9158e73b2e4c9fd1a565e1e5d1bc3af5/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55a035529240] using SAR=1/1
# [libx264 @ 0x55a035529240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55a035529240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55a035529240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-htl_max-shear-0.05_id-9158e73b2e4c9fd1a565e1e5d1bc3af5.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=161 q=-1.0 Lsize=    3627kB time=00:00:19.80 bitrate=1500.7kbits/s speed=15.9x
# video:3624kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.089305%
# [libx264 @ 0x55a035529240] frame I:1     Avg QP:16.32  size:118372
# [libx264 @ 0x55a035529240] frame P:52    Avg QP:18.69  size: 51163
# [libx264 @ 0x55a035529240] frame B:148   Avg QP:26.55  size:  6293
# [libx264 @ 0x55a035529240] consecutive B-frames:  1.5%  1.0%  0.0% 97.5%
# [libx264 @ 0x55a035529240] mb I  I16..4: 43.2%  0.0% 56.8%
# [libx264 @ 0x55a035529240] mb P  I16..4:  0.9%  0.0%  5.0%  P16..4: 11.6% 15.3% 15.6%  0.0%  0.0%    skip:51.5%
# [libx264 @ 0x55a035529240] mb B  I16..4:  0.0%  0.0%  0.1%  B16..8: 21.5%  7.5%  3.1%  direct: 3.7%  skip:64.1%  L0:30.1% L1:37.9% BI:32.0%
# [libx264 @ 0x55a035529240] coded y,u,v intra: 74.6% 74.1% 72.4% inter: 19.4% 8.8% 10.2%
# [libx264 @ 0x55a035529240] i16 v,h,dc,p: 83% 11%  6%  0%
# [libx264 @ 0x55a035529240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 18% 15%  7% 10%  8% 11%  7% 12%
# [libx264 @ 0x55a035529240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55a035529240] ref P L0: 48.3% 28.8% 12.1% 10.7%
# [libx264 @ 0x55a035529240] ref B L0: 90.6%  7.6%  1.8%
# [libx264 @ 0x55a035529240] ref B L1: 94.2%  5.8%
# [libx264 @ 0x55a035529240] kb/s:1476.70
# 100%|██████████| 201/201 [11:20<00:00,  3.39s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/9158e73b2e4c9fd1a565e1e5d1bc3af5/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55ad12ec2240] using SAR=1/1
# [libx264 @ 0x55ad12ec2240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55ad12ec2240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55ad12ec2240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-htl_max-shear-0.08_id-9158e73b2e4c9fd1a565e1e5d1bc3af5.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=143 q=-1.0 Lsize=    5077kB time=00:00:19.80 bitrate=2100.5kbits/s speed=14.1x
# video:5074kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.064095%
# [libx264 @ 0x55ad12ec2240] frame I:1     Avg QP:16.85  size:110883
# [libx264 @ 0x55ad12ec2240] frame P:51    Avg QP:19.08  size: 60983
# [libx264 @ 0x55ad12ec2240] frame B:149   Avg QP:26.41  size: 13246
# [libx264 @ 0x55ad12ec2240] consecutive B-frames:  0.5%  2.0%  0.0% 97.5%
# [libx264 @ 0x55ad12ec2240] mb I  I16..4: 43.2%  0.0% 56.8%
# [libx264 @ 0x55ad12ec2240] mb P  I16..4:  1.0%  0.0% 10.6%  P16..4:  8.9% 12.8% 15.2%  0.0%  0.0%    skip:51.5%
# [libx264 @ 0x55ad12ec2240] mb B  I16..4:  0.0%  0.0%  0.4%  B16..8: 19.2% 10.9%  5.5%  direct: 5.0%  skip:59.0%  L0:34.0% L1:34.9% BI:31.1%
# [libx264 @ 0x55ad12ec2240] coded y,u,v intra: 84.0% 83.9% 81.7% inter: 25.8% 12.6% 14.5%
# [libx264 @ 0x55ad12ec2240] i16 v,h,dc,p: 82% 13%  6%  0%
# [libx264 @ 0x55ad12ec2240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 18% 16%  7% 10%  8% 11%  7% 12%
# [libx264 @ 0x55ad12ec2240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55ad12ec2240] ref P L0: 43.1% 28.1% 16.8% 12.0%
# [libx264 @ 0x55ad12ec2240] ref B L0: 90.2%  7.6%  2.3%
# [libx264 @ 0x55ad12ec2240] ref B L1: 95.2%  4.8%
# [libx264 @ 0x55ad12ec2240] kb/s:2067.55
# 100%|██████████| 201/201 [11:21<00:00,  3.39s/it]
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/media/ian/Data2/monk/2d-osc-shear/workspace/9158e73b2e4c9fd1a565e1e5d1bc3af5/videos/softness-movie/softness-movie-*.png':
#   Duration: 00:00:20.10, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 900x600 [SAR 5906:5906 DAR 3:2], 10 fps, 10 tbr, 10 tbn, 10 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55f35607e240] using SAR=1/1
# [libx264 @ 0x55f35607e240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55f35607e240] profile High 4:4:4 Predictive, level 3.1, 4:4:4, 8-bit
# [libx264 @ 0x55f35607e240] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x1:0x111 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=0 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=10 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'videos/softness-movie-htl_max-shear-0.12_id-9158e73b2e4c9fd1a565e1e5d1bc3af5.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv444p, 900x600 [SAR 1:1 DAR 3:2], q=-1--1, 10 fps, 10240 tbn, 10 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  201 fps=132 q=-1.0 Lsize=    6398kB time=00:00:19.80 bitrate=2647.1kbits/s speed=  13x
# video:6395kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.051342%
# [libx264 @ 0x55f35607e240] frame I:1     Avg QP:17.34  size:101771
# [libx264 @ 0x55f35607e240] frame P:50    Avg QP:19.53  size: 69106
# [libx264 @ 0x55f35607e240] frame B:150   Avg QP:26.46  size: 19937
# [libx264 @ 0x55f35607e240] consecutive B-frames:  0.5%  0.0%  0.0% 99.5%
# [libx264 @ 0x55f35607e240] mb I  I16..4: 43.3%  0.0% 56.7%
# [libx264 @ 0x55f35607e240] mb P  I16..4:  0.9%  0.0% 16.4%  P16..4:  6.6% 10.3% 14.2%  0.0%  0.0%    skip:51.6%
# [libx264 @ 0x55f35607e240] mb B  I16..4:  0.0%  0.0%  1.2%  B16..8: 17.1% 12.5%  7.3%  direct: 5.3%  skip:56.6%  L0:35.1% L1:33.9% BI:31.0%
# [libx264 @ 0x55f35607e240] coded y,u,v intra: 89.7% 89.7% 87.1% inter: 29.4% 15.5% 17.3%
# [libx264 @ 0x55f35607e240] i16 v,h,dc,p: 87%  8%  5%  0%
# [libx264 @ 0x55f35607e240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11% 18% 16%  8% 10%  8% 11%  7% 12%
# [libx264 @ 0x55f35607e240] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55f35607e240] ref P L0: 40.0% 27.5% 19.2% 13.3%
# [libx264 @ 0x55f35607e240] ref B L0: 88.5%  8.4%  3.0%
# [libx264 @ 0x55f35607e240] ref B L1: 95.2%  4.8%
# [libx264 @ 0x55f35607e240] kb/s:2606.01
# c6d7afd0de62bfa16d05da47815227eb
# bf92a185d043ce3ef666e05e427c7e76
# a8f2c249ed85533b56b0729b7ab96d18
