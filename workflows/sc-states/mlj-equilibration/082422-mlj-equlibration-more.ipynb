# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm, colors
import glob
import itertools

from numba import njit, vectorize, float32

from typing import Callable, Optional, Union

import hoomd
import gsd.hoomd

import sys
import time
import pickle
import gc

import signac

# %%
from monk import nb, prep, pair, render, utils, grid
import freud

# %%
class VerifyEquilibrium(hoomd.custom.Action):
    """Computes dynamics to verify equilibration."""

    def __init__(self, k: float = None):
        self.last_pos = None
        self.last_image = None
        self.last_tstep = None
        self.k = 7.14
        self.alphas = []
        self.Ds = []
        self.msds = []
        self.sisfs = []
        self.tsteps = []
    
    def act(self, timestep):
        
        if self.last_pos is None:
            snap = self._state.get_snapshot()
            self.last_pos = snap.particles.position
            self.last_image = snap.particles.image
            self.first_tstep = timestep
            self.last_tstep = timestep
            self.last_msd = 0.0
            self.alpha_time = 0.0
            self.measure_D = False
            self.measured_D = 0.0
            self.measured_alpha = 0.0
        else:
            if self.measure_D:
                dt = self._state._simulation.operations.integrator.dt
                if (timestep - self.last_tstep)*dt > self.measured_alpha:
                    snap = self._state.get_snapshot()
                    pos = snap.particles.position
                    image = snap.particles.image
                    sim_box = self._state.box
                    if sim_box.is2D:
                        dim = 2
                    else:
                        dim = 3
                    box = freud.box.Box.from_box(sim_box)
                    unwrapped_pos = box.unwrap(pos, image - self.last_image)
                    msd = np.mean(np.sum(np.square(unwrapped_pos - self.last_pos), axis=-1))
                    self.msds.append(msd)
                    self.tsteps.append(timestep - self.first_tstep)
                    D = (msd - self.last_msd) / (timestep - self.last_tstep) / dt / (2 * dim)
                    self.measured_D = D
                    self.Ds.append(self.measured_D)
                    self.alphas.append(self.measured_alpha)
                    self.measure_D = False
                    self.alpha_time = 0.0
                    self.first_tstep = timestep
                    self.last_pos = snap.particles.position
                    self.last_image = snap.particles.image
            else:
                snap = self._state.get_snapshot()
                dt = self._state._simulation.operations.integrator.dt
                pos = snap.particles.position
                image = snap.particles.image
                sim_box = self._state.box
                if sim_box.is2D:
                    dim = 2
                else:
                    dim = 3
                box = freud.box.Box.from_box(sim_box)
                unwrapped_pos = box.unwrap(pos, image - self.last_image)
                msd = np.mean(np.sum(np.square(unwrapped_pos - self.last_pos), axis=-1))
                self.msds.append(msd)
                self.tsteps.append(timestep - self.first_tstep)
                self.last_tstep = timestep
                self.last_msd = msd
                

                x = self.k * np.linalg.norm(pos - self.last_pos, axis=-1)
                sisf = np.mean(np.sin(x)/x)
                self.sisfs.append(sisf)

                # print(f"{D} {sisf}")

                self.alpha_time = (timestep - self.first_tstep) * dt
                if sisf < np.exp(-1.0):
                    self.measure_D = True
                    self.measured_alpha = self.alpha_time

# %%
project: signac.Project = signac.init_project("mlj-equilibration")

# %% [markdown]
# ## Lets look at more systems
#
# - More densities for the standard KA mixture
# - Interpolation between KA and WCA

# %%
gridspec = {
    'phi-temp': zip(
        [1.3, 1.1, 1.0],
        [3.0, 2.0, 2.0]
    )
}

N = 2**15

sps = list(grid(gridspec))

# %%
len(sps)
# Out:
# 3

# %%
i = 0
for _replica in range(3):
    for grid_sp in sps:
        sp = {"N": N, "seed": i, "version": 2, "potential": "lj"}
        phi_temp = grid_sp['phi-temp']
        sp.update({"phi": phi_temp[0], "temp": phi_temp[1]})
        job = project.open_job(sp)
        job.init()
        print(sp)
        i += 1
# Out:
# {'N': 32768, 'seed': 0, 'version': 2, 'potential': 'lj', 'phi': 1.3, 'temp': 3.0}
# {'N': 32768, 'seed': 1, 'version': 2, 'potential': 'lj', 'phi': 1.1, 'temp': 2.0}
# {'N': 32768, 'seed': 2, 'version': 2, 'potential': 'lj', 'phi': 1.0, 'temp': 2.0}
# {'N': 32768, 'seed': 3, 'version': 2, 'potential': 'lj', 'phi': 1.3, 'temp': 3.0}
# {'N': 32768, 'seed': 4, 'version': 2, 'potential': 'lj', 'phi': 1.1, 'temp': 2.0}
# {'N': 32768, 'seed': 5, 'version': 2, 'potential': 'lj', 'phi': 1.0, 'temp': 2.0}
# {'N': 32768, 'seed': 6, 'version': 2, 'potential': 'lj', 'phi': 1.3, 'temp': 3.0}
# {'N': 32768, 'seed': 7, 'version': 2, 'potential': 'lj', 'phi': 1.1, 'temp': 2.0}
# {'N': 32768, 'seed': 8, 'version': 2, 'potential': 'lj', 'phi': 1.0, 'temp': 2.0}

# %%
gridspec = {
    'phi-epsilon-temp': zip(
        [1.2, 1.2, 1.2],
        [0.66, 0.33, 0.0],
        [2.0, 2.0, 2.0]
    )
}

N = 2**15

sps = list(grid(gridspec))

# %%
len(sps)
# Out:
# 3

# %%
i = 0
for _replica in range(3):
    for grid_sp in sps:
        phi_epsilon_temp = grid_sp['phi-epsilon-temp']
        if phi_epsilon_temp[1] == 0.0:
            pot = "wca"
        else:
            pot = "wlj"
        sp = {"N": N, "seed": i, "version": 2, "potential": pot}
        
        sp.update({"phi": phi_epsilon_temp[0], "epsilon_a": phi_epsilon_temp[1], "temp": phi_epsilon_temp[2]})
        job = project.open_job(sp)
        job.init()
        print(sp)
        i += 1
# Out:
# {'N': 32768, 'seed': 0, 'version': 2, 'potential': 'wlj', 'phi': 1.2, 'epsilon_a': 0.66, 'temp': 2.0}
# {'N': 32768, 'seed': 1, 'version': 2, 'potential': 'wlj', 'phi': 1.2, 'epsilon_a': 0.33, 'temp': 2.0}
# {'N': 32768, 'seed': 2, 'version': 2, 'potential': 'wca', 'phi': 1.2, 'epsilon_a': 0.0, 'temp': 2.0}
# {'N': 32768, 'seed': 3, 'version': 2, 'potential': 'wlj', 'phi': 1.2, 'epsilon_a': 0.66, 'temp': 2.0}
# {'N': 32768, 'seed': 4, 'version': 2, 'potential': 'wlj', 'phi': 1.2, 'epsilon_a': 0.33, 'temp': 2.0}
# {'N': 32768, 'seed': 5, 'version': 2, 'potential': 'wca', 'phi': 1.2, 'epsilon_a': 0.0, 'temp': 2.0}
# {'N': 32768, 'seed': 6, 'version': 2, 'potential': 'wlj', 'phi': 1.2, 'epsilon_a': 0.66, 'temp': 2.0}
# {'N': 32768, 'seed': 7, 'version': 2, 'potential': 'wlj', 'phi': 1.2, 'epsilon_a': 0.33, 'temp': 2.0}
# {'N': 32768, 'seed': 8, 'version': 2, 'potential': 'wca', 'phi': 1.2, 'epsilon_a': 0.0, 'temp': 2.0}

# %%
project.num_jobs()
# Out:
# 36

# %%
import math
def roundup(x):
    return 10**math.ceil(math.log10(x))

# %%
for job in project.find_jobs({"version": 2}):
    print(job, job.sp)
# Out:
# f909e0d5ded9b8d44d047be0c366e2d8 {'N': 32768, 'seed': 2, 'version': 2, 'potential': 'lj', 'phi': 1.0, 'temp': 2.0}
# f77c6b09e15c8a3edd6850045c54f6e9 {'N': 32768, 'seed': 3, 'version': 2, 'potential': 'lj', 'phi': 1.3, 'temp': 3.0}
# 5591b93e5b065dc91f8ea5fafb1142cb {'N': 32768, 'seed': 7, 'version': 2, 'potential': 'lj', 'phi': 1.1, 'temp': 2.0}
# 8cbf2fbf8aabb4f86a527aa4fe2654e5 {'N': 32768, 'seed': 8, 'version': 2, 'potential': 'lj', 'phi': 1.0, 'temp': 2.0}
# d463590d19a3e65e386b494c9da55a29 {'N': 32768, 'seed': 0, 'version': 2, 'potential': 'lj', 'phi': 1.3, 'temp': 3.0}
# 6d0e26dc31c06d7fcf8664fb90d6dfe8 {'N': 32768, 'seed': 7, 'version': 2, 'potential': 'wlj', 'phi': 1.2, 'epsilon_a': 0.33, 'temp': 2.0}
# 6469592346c78bddc3a7c5a4e3f07e24 {'N': 32768, 'seed': 4, 'version': 2, 'potential': 'wlj', 'phi': 1.2, 'epsilon_a': 0.33, 'temp': 2.0}
# d33a93db90ea789c91cef08f39e93387 {'N': 32768, 'seed': 1, 'version': 2, 'potential': 'wlj', 'phi': 1.2, 'epsilon_a': 0.33, 'temp': 2.0}
# b7ff611cf279956f8172e6b3e2eb0d81 {'N': 32768, 'seed': 2, 'version': 2, 'potential': 'wca', 'phi': 1.2, 'epsilon_a': 0.0, 'temp': 2.0}
# 28b4429eed5f428db7917ba7ad3a8bb3 {'N': 32768, 'seed': 6, 'version': 2, 'potential': 'lj', 'phi': 1.3, 'temp': 3.0}
# 1e676c088487b7b767fd88808059970d {'N': 32768, 'seed': 6, 'version': 2, 'potential': 'wlj', 'phi': 1.2, 'epsilon_a': 0.66, 'temp': 2.0}
# c043c1e02b9cfc4ce2e9e10a15055ac4 {'N': 32768, 'seed': 1, 'version': 2, 'potential': 'lj', 'phi': 1.1, 'temp': 2.0}
# da7bee5bed40339688289a3cc4f0e633 {'N': 32768, 'seed': 3, 'version': 2, 'potential': 'wlj', 'phi': 1.2, 'epsilon_a': 0.66, 'temp': 2.0}
# 2adb6e9af8dded4ea48c5cb63e5162eb {'N': 32768, 'seed': 0, 'version': 2, 'potential': 'wlj', 'phi': 1.2, 'epsilon_a': 0.66, 'temp': 2.0}
# 4d2d336a8192ae621bc1a0869acbe077 {'N': 32768, 'seed': 8, 'version': 2, 'potential': 'wca', 'phi': 1.2, 'epsilon_a': 0.0, 'temp': 2.0}
# c916c092e6400cff262255ae157d882c {'N': 32768, 'seed': 5, 'version': 2, 'potential': 'lj', 'phi': 1.0, 'temp': 2.0}
# 8de6f44e13fbbafaf7f8347aee807462 {'N': 32768, 'seed': 4, 'version': 2, 'potential': 'lj', 'phi': 1.1, 'temp': 2.0}
# 691827fe5bca905e61650133bf7392c2 {'N': 32768, 'seed': 5, 'version': 2, 'potential': 'wca', 'phi': 1.2, 'epsilon_a': 0.0, 'temp': 2.0}

# %%
for job in project.find_jobs({"version": 2}):
    assert isinstance(job, signac.Project.Job)
    print("SP:", job.sp)
    sp = job.sp

    alpha_thresh = project.doc["threshold_alpha"]
    temp_step = project.doc["temp_step"]
    alpha_iters = project.doc["alpha_iters"]
    equil_steps = project.doc["equil_steps"]

    run_duration = 100_000

    if len(glob.glob(job.fn("not-equil_*.gsd"))) > 0:
        print(f"Job already reached threshold")
        continue

    already_done = sorted(glob.glob(job.fn("equil_*.gsd")))
    if len(already_done) > 0:
        state = already_done[0]
        print(f"Resuming from a checkpoint: {state.split('/')[-1]}")
        sim = hoomd.Simulation(hoomd.device.GPU(), seed=sp["seed"]+1)
        sim.create_state_from_gsd(state)

        integrator = hoomd.md.Integrator(dt=0.001)
        tree = hoomd.md.nlist.Tree(0.3)
        if sp["potential"] == "lj":
            print("Using LJ")
            mlj = pair.KA_LJ(tree)
        elif sp["potential"] == "wlj":
            print("Using WLJ")
            mlj = pair.KA_WLJ(tree, epsilon_a=sp["epsilon_a"])
        elif sp["potential"] == "wca":
            print("Using WCA")
            mlj = pair.KA_WCA(tree)
        else:
            raise ValueError(f"Unknown potential {sp['potential']}")

        temp = state.split("equil_")[-1].split(".gsd")[0]

        nvt = hoomd.md.methods.NVT(hoomd.filter.All(), float(temp) - temp_step, 0.1)
        integrator.forces = [mlj]
        integrator.methods = [nvt]

        sim.operations.integrator = integrator

        temp_gsd = temp.replace(".", "_")
        
        with job.data:
            max_alpha_steps = roundup(int(np.max(job.data[f"{temp_gsd}/alphas"][:])*1000))
        if max_alpha_steps > run_duration:
            run_duration = max_alpha_steps
    else:
        print("Initializing new state")
        sim = prep.quick_sim(sp["N"], sp["phi"], hoomd.device.GPU(), ratios=[80, 20], diams=[1.0, 0.88], seed=sp["seed"])

        integrator = hoomd.md.Integrator(dt=0.001)
        tree = hoomd.md.nlist.Tree(0.3)
        if sp["potential"] == "lj":
            print("Using LJ")
            mlj = pair.KA_LJ(tree)
        elif sp["potential"] == "wlj":
            print("Using WLJ")
            mlj = pair.KA_WLJ(tree, epsilon_a=sp["epsilon_a"])
        elif sp["potential"] == "wca":
            print("Using WCA")
            mlj = pair.KA_WCA(tree)
        else:
            raise ValueError(f"Unknown potential {sp['potential']}")

        nvt = hoomd.md.methods.NVT(hoomd.filter.All(), sp["temp"], 0.1)
        integrator.forces = [mlj]
        integrator.methods = [nvt]

        sim.operations.integrator = integrator
        
        sim.state.thermalize_particle_momenta(hoomd.filter.All(), sp["temp"])

        sim.run(0)
        nvt.thermalize_thermostat_dof()
        
        hoomd.write.GSD.write(sim.state, job.fn("init.gsd"))

    alpha_thresh_met = False
    while not alpha_thresh_met:

        print(f"temp: {nvt.kT(sim.timestep):.1f}", end="")

        sim.run(equil_steps)

        action = VerifyEquilibrium()
        custom_action = hoomd.update.CustomUpdater(hoomd.trigger.Periodic(run_duration//1_000), action)
        sim.operations.updaters.clear()
        sim.operations.updaters.append(custom_action)

        while len(action.alphas) < alpha_iters:
            sim.run(run_duration)
            if (len(action.alphas) > 0 and np.max(action.alphas) > alpha_thresh) or action.alpha_time > alpha_thresh:
                alpha_thresh_met = True
                break
            
        cur_temp = nvt.kT(sim.timestep)
        job.data[f"{cur_temp:.1f}/tsteps".replace(".", "_")] = np.array(action.tsteps)
        job.data[f"{cur_temp:.1f}/msds".replace(".", "_")] = np.array(action.msds)
        job.data[f"{cur_temp:.1f}/sisfs".replace(".", "_")] = np.array(action.sisfs)
        job.data[f"{cur_temp:.1f}/alphas".replace(".", "_")] = np.array(action.alphas)
        job.data[f"{cur_temp:.1f}/Ds".replace(".", "_")] = np.array(action.Ds)
        if alpha_thresh_met:
            print(" ALPHA THRESHOLD MET")
            hoomd.write.GSD.write(sim.state, job.fn(f"not-equil_{cur_temp:.1f}.gsd"))
        else:
            print(f" alpha: {np.max(action.alphas):.2f} run_duration: {run_duration}")
            max_alpha_steps = roundup(int(np.max(action.alphas)*1000))
            if max_alpha_steps > run_duration:
                run_duration = max_alpha_steps
            hoomd.write.GSD.write(sim.state, job.fn(f"equil_{cur_temp:.1f}.gsd"))

        nvt.kT = cur_temp - temp_step

    del sim
# Out:
# SP: {'N': 32768, 'seed': 2, 'version': 2, 'potential': 'lj', 'phi': 1.0, 'temp': 2.0}
# Job already reached threshold
# SP: {'N': 32768, 'seed': 3, 'version': 2, 'potential': 'lj', 'phi': 1.3, 'temp': 3.0}
# Job already reached threshold
# SP: {'N': 32768, 'seed': 7, 'version': 2, 'potential': 'lj', 'phi': 1.1, 'temp': 2.0}
# Resuming from a checkpoint: equil_0.4.gsd
# Using LJ
# temp: 0.3 alpha: 351.90 run_duration: 100000
# temp: 0.2 ALPHA THRESHOLD MET
# SP: {'N': 32768, 'seed': 8, 'version': 2, 'potential': 'lj', 'phi': 1.0, 'temp': 2.0}
# Job already reached threshold
# SP: {'N': 32768, 'seed': 0, 'version': 2, 'potential': 'lj', 'phi': 1.3, 'temp': 3.0}
# Initializing new state
# Using LJ
# temp: 3.0 alpha: 0.30 run_duration: 100000
# temp: 2.9 alpha: 0.40 run_duration: 100000
# temp: 2.8 alpha: 0.40 run_duration: 100000
# temp: 2.7 alpha: 0.40 run_duration: 100000
# temp: 2.6 alpha: 0.40 run_duration: 100000
# temp: 2.5 alpha: 0.40 run_duration: 100000
# temp: 2.4 alpha: 0.40 run_duration: 100000
# temp: 2.3 alpha: 0.50 run_duration: 100000
# temp: 2.2 alpha: 0.50 run_duration: 100000
# temp: 2.1 alpha: 0.50 run_duration: 100000
# temp: 2.0 alpha: 0.60 run_duration: 100000
# temp: 1.9 alpha: 0.60 run_duration: 100000
# temp: 1.8 alpha: 0.70 run_duration: 100000
# temp: 1.7 alpha: 0.80 run_duration: 100000
# temp: 1.6 alpha: 0.90 run_duration: 100000
# temp: 1.5 alpha: 1.00 run_duration: 100000
# temp: 1.4 alpha: 1.20 run_duration: 100000
# temp: 1.3 alpha: 1.60 run_duration: 100000
# temp: 1.2 alpha: 2.10 run_duration: 100000
# temp: 1.1 alpha: 3.00 run_duration: 100000
# temp: 1.0 alpha: 5.10 run_duration: 100000
# temp: 0.9 alpha: 10.40 run_duration: 100000
# temp: 0.8 alpha: 36.80 run_duration: 100000
# temp: 0.7 alpha: 481.70 run_duration: 100000
# temp: 0.6 ALPHA THRESHOLD MET
# SP: {'N': 32768, 'seed': 7, 'version': 2, 'potential': 'wlj', 'phi': 1.2, 'epsilon_a': 0.33, 'temp': 2.0}
# Initializing new state
# Using WLJ
# temp: 2.0 alpha: 0.40 run_duration: 100000
# temp: 1.9 alpha: 0.40 run_duration: 100000
# temp: 1.8 alpha: 0.40 run_duration: 100000
# temp: 1.7 alpha: 0.40 run_duration: 100000
# temp: 1.6 alpha: 0.50 run_duration: 100000
# temp: 1.5 alpha: 0.50 run_duration: 100000
# temp: 1.4 alpha: 0.60 run_duration: 100000
# temp: 1.3 alpha: 0.60 run_duration: 100000
# temp: 1.2 alpha: 0.70 run_duration: 100000
# temp: 1.1 alpha: 0.80 run_duration: 100000
# temp: 1.0 alpha: 1.00 run_duration: 100000
# temp: 0.9 alpha: 1.20 run_duration: 100000
# temp: 0.8 alpha: 1.50 run_duration: 100000
# temp: 0.7 alpha: 2.20 run_duration: 100000
# temp: 0.6 alpha: 4.00 run_duration: 100000
# temp: 0.5 alpha: 10.00 run_duration: 100000
# temp: 0.4 alpha: 76.90 run_duration: 100000
# temp: 0.3 ALPHA THRESHOLD MET
# SP: {'N': 32768, 'seed': 4, 'version': 2, 'potential': 'wlj', 'phi': 1.2, 'epsilon_a': 0.33, 'temp': 2.0}
# Initializing new state
# Using WLJ
# temp: 2.0 alpha: 0.40 run_duration: 100000
# temp: 1.9 alpha: 0.40 run_duration: 100000
# temp: 1.8 alpha: 0.40 run_duration: 100000
# temp: 1.7 alpha: 0.50 run_duration: 100000
# temp: 1.6 alpha: 0.50 run_duration: 100000
# temp: 1.5 alpha: 0.50 run_duration: 100000
# temp: 1.4 alpha: 0.60 run_duration: 100000
# temp: 1.3 alpha: 0.60 run_duration: 100000
# temp: 1.2 alpha: 0.70 run_duration: 100000
# temp: 1.1 alpha: 0.80 run_duration: 100000
# temp: 1.0 alpha: 1.00 run_duration: 100000
# temp: 0.9 alpha: 1.20 run_duration: 100000
# temp: 0.8 alpha: 1.60 run_duration: 100000
# temp: 0.7 alpha: 2.20 run_duration: 100000
# temp: 0.6 alpha: 4.00 run_duration: 100000
# temp: 0.5 alpha: 10.60 run_duration: 100000
# temp: 0.4 alpha: 89.40 run_duration: 100000
# temp: 0.3 ALPHA THRESHOLD MET
# SP: {'N': 32768, 'seed': 1, 'version': 2, 'potential': 'wlj', 'phi': 1.2, 'epsilon_a': 0.33, 'temp': 2.0}
# Initializing new state
# Using WLJ
# temp: 2.0 alpha: 0.40 run_duration: 100000
# temp: 1.9 alpha: 0.40 run_duration: 100000
# temp: 1.8 alpha: 0.40 run_duration: 100000
# temp: 1.7 alpha: 0.50 run_duration: 100000
# temp: 1.6 alpha: 0.50 run_duration: 100000
# temp: 1.5 alpha: 0.50 run_duration: 100000
# temp: 1.4 alpha: 0.60 run_duration: 100000
# temp: 1.3 alpha: 0.60 run_duration: 100000
# temp: 1.2 alpha: 0.70 run_duration: 100000
# temp: 1.1 alpha: 0.80 run_duration: 100000
# temp: 1.0 alpha: 1.00 run_duration: 100000
# temp: 0.9 alpha: 1.20 run_duration: 100000
# temp: 0.8 alpha: 1.50 run_duration: 100000
# temp: 0.7 alpha: 2.30 run_duration: 100000
# temp: 0.6 alpha: 3.90 run_duration: 100000
# temp: 0.5 alpha: 9.70 run_duration: 100000
# temp: 0.4 alpha: 79.30 run_duration: 100000
# temp: 0.3 ALPHA THRESHOLD MET
# SP: {'N': 32768, 'seed': 2, 'version': 2, 'potential': 'wca', 'phi': 1.2, 'epsilon_a': 0.0, 'temp': 2.0}
# Initializing new state
# Using WCA
# temp: 2.0 alpha: 0.40 run_duration: 100000
# temp: 1.9 alpha: 0.40 run_duration: 100000
# temp: 1.8 alpha: 0.40 run_duration: 100000
# temp: 1.7 alpha: 0.40 run_duration: 100000
# temp: 1.6 alpha: 0.50 run_duration: 100000
# temp: 1.5 alpha: 0.50 run_duration: 100000
# temp: 1.4 alpha: 0.50 run_duration: 100000
# temp: 1.3 alpha: 0.60 run_duration: 100000
# temp: 1.2 alpha: 0.70 run_duration: 100000
# temp: 1.1 alpha: 0.80 run_duration: 100000
# temp: 1.0 alpha: 0.90 run_duration: 100000
# temp: 0.9 alpha: 1.10 run_duration: 100000
# temp: 0.8 alpha: 1.30 run_duration: 100000
# temp: 0.7 alpha: 1.80 run_duration: 100000
# temp: 0.6 alpha: 2.90 run_duration: 100000
# temp: 0.5 alpha: 5.50 run_duration: 100000
# temp: 0.4 alpha: 21.10 run_duration: 100000
# temp: 0.3 alpha: 831.80 run_duration: 100000
# temp: 0.2 ALPHA THRESHOLD MET
# SP: {'N': 32768, 'seed': 6, 'version': 2, 'potential': 'lj', 'phi': 1.3, 'temp': 3.0}
# Job already reached threshold
# SP: {'N': 32768, 'seed': 6, 'version': 2, 'potential': 'wlj', 'phi': 1.2, 'epsilon_a': 0.66, 'temp': 2.0}
# Initializing new state
# Using WLJ
# temp: 2.0 alpha: 0.40 run_duration: 100000
# temp: 1.9 alpha: 0.40 run_duration: 100000
# temp: 1.8 alpha: 0.40 run_duration: 100000
# temp: 1.7 alpha: 0.50 run_duration: 100000
# temp: 1.6 alpha: 0.50 run_duration: 100000
# temp: 1.5 alpha: 0.50 run_duration: 100000
# temp: 1.4 alpha: 0.60 run_duration: 100000
# temp: 1.3 alpha: 0.70 run_duration: 100000
# temp: 1.2 alpha: 0.80 run_duration: 100000
# temp: 1.1 alpha: 0.90 run_duration: 100000
# temp: 1.0 alpha: 1.10 run_duration: 100000
# temp: 0.9 alpha: 1.40 run_duration: 100000
# temp: 0.8 alpha: 1.90 run_duration: 100000
# temp: 0.7 alpha: 3.00 run_duration: 100000
# temp: 0.6 alpha: 6.00 run_duration: 100000
# temp: 0.5 alpha: 24.90 run_duration: 100000
# temp: 0.4 alpha: 982.60 run_duration: 100000
# temp: 0.3 ALPHA THRESHOLD MET
# SP: {'N': 32768, 'seed': 1, 'version': 2, 'potential': 'lj', 'phi': 1.1, 'temp': 2.0}
# Initializing new state
# Using LJ
# temp: 2.0 alpha: 0.30 run_duration: 100000
# temp: 1.9 alpha: 0.30 run_duration: 100000
# temp: 1.8 alpha: 0.30 run_duration: 100000
# temp: 1.7 alpha: 0.40 run_duration: 100000
# temp: 1.6 alpha: 0.40 run_duration: 100000
# temp: 1.5 alpha: 0.40 run_duration: 100000
# temp: 1.4 alpha: 0.40 run_duration: 100000
# temp: 1.3 alpha: 0.50 run_duration: 100000
# temp: 1.2 alpha: 0.50 run_duration: 100000
# temp: 1.1 alpha: 0.60 run_duration: 100000
# temp: 1.0 alpha: 0.60 run_duration: 100000
# temp: 0.9 alpha: 0.70 run_duration: 100000
# temp: 0.8 alpha: 0.90 run_duration: 100000
# temp: 0.7 alpha: 1.10 run_duration: 100000
# temp: 0.6 alpha: 1.60 run_duration: 100000
# temp: 0.5 alpha: 2.90 run_duration: 100000
# temp: 0.4 alpha: 9.50 run_duration: 100000
# temp: 0.3 alpha: 271.10 run_duration: 100000
# temp: 0.2 ALPHA THRESHOLD MET
# SP: {'N': 32768, 'seed': 3, 'version': 2, 'potential': 'wlj', 'phi': 1.2, 'epsilon_a': 0.66, 'temp': 2.0}
# Initializing new state
# Using WLJ
# temp: 2.0 alpha: 0.40 run_duration: 100000
# temp: 1.9 alpha: 0.40 run_duration: 100000
# temp: 1.8 alpha: 0.40 run_duration: 100000
# temp: 1.7 alpha: 0.50 run_duration: 100000
# temp: 1.6 alpha: 0.50 run_duration: 100000
# temp: 1.5 alpha: 0.50 run_duration: 100000
# temp: 1.4 alpha: 0.60 run_duration: 100000
# temp: 1.3 alpha: 0.70 run_duration: 100000
# temp: 1.2 alpha: 0.80 run_duration: 100000
# temp: 1.1 alpha: 0.90 run_duration: 100000
# temp: 1.0 alpha: 1.10 run_duration: 100000
# temp: 0.9 alpha: 1.40 run_duration: 100000
# temp: 0.8 alpha: 1.90 run_duration: 100000
# temp: 0.7 alpha: 3.00 run_duration: 100000
# temp: 0.6 alpha: 6.30 run_duration: 100000
# temp: 0.5 alpha: 22.90 run_duration: 100000
# temp: 0.4 alpha: 969.50 run_duration: 100000
# temp: 0.3 ALPHA THRESHOLD MET
# SP: {'N': 32768, 'seed': 0, 'version': 2, 'potential': 'wlj', 'phi': 1.2, 'epsilon_a': 0.66, 'temp': 2.0}
# Initializing new state
# Using WLJ
# temp: 2.0 alpha: 0.40 run_duration: 100000
# temp: 1.9 alpha: 0.40 run_duration: 100000
# temp: 1.8 alpha: 0.40 run_duration: 100000
# temp: 1.7 alpha: 0.50 run_duration: 100000
# temp: 1.6 alpha: 0.50 run_duration: 100000
# temp: 1.5 alpha: 0.50 run_duration: 100000
# temp: 1.4 alpha: 0.60 run_duration: 100000
# temp: 1.3 alpha: 0.70 run_duration: 100000
# temp: 1.2 alpha: 0.80 run_duration: 100000
# temp: 1.1 alpha: 0.90 run_duration: 100000
# temp: 1.0 alpha: 1.10 run_duration: 100000
# temp: 0.9 alpha: 1.30 run_duration: 100000
# temp: 0.8 alpha: 1.90 run_duration: 100000
# temp: 0.7 alpha: 2.90 run_duration: 100000
# temp: 0.6 alpha: 6.20 run_duration: 100000
# temp: 0.5 alpha: 23.80 run_duration: 100000
# temp: 0.4 alpha: 996.40 run_duration: 100000
# temp: 0.3 ALPHA THRESHOLD MET
# SP: {'N': 32768, 'seed': 8, 'version': 2, 'potential': 'wca', 'phi': 1.2, 'epsilon_a': 0.0, 'temp': 2.0}
# Initializing new state
# Using WCA
# temp: 2.0 alpha: 0.40 run_duration: 100000
# temp: 1.9 alpha: 0.40 run_duration: 100000
# temp: 1.8 alpha: 0.40 run_duration: 100000
# temp: 1.7 alpha: 0.40 run_duration: 100000
# temp: 1.6 alpha: 0.50 run_duration: 100000
# temp: 1.5 alpha: 0.50 run_duration: 100000
# temp: 1.4 alpha: 0.50 run_duration: 100000
# temp: 1.3 alpha: 0.60 run_duration: 100000
# temp: 1.2 alpha: 0.70 run_duration: 100000
# temp: 1.1 alpha: 0.80 run_duration: 100000
# temp: 1.0 alpha: 0.90 run_duration: 100000
# temp: 0.9 alpha: 1.10 run_duration: 100000
# temp: 0.8 alpha: 1.30 run_duration: 100000
# temp: 0.7 alpha: 1.80 run_duration: 100000
# temp: 0.6 alpha: 2.80 run_duration: 100000
# temp: 0.5 alpha: 5.80 run_duration: 100000
# temp: 0.4 alpha: 20.20 run_duration: 100000
# temp: 0.3 alpha: 830.60 run_duration: 100000
# temp: 0.2 ALPHA THRESHOLD MET
# SP: {'N': 32768, 'seed': 5, 'version': 2, 'potential': 'lj', 'phi': 1.0, 'temp': 2.0}
# Job already reached threshold
# SP: {'N': 32768, 'seed': 4, 'version': 2, 'potential': 'lj', 'phi': 1.1, 'temp': 2.0}
# Initializing new state
# Using LJ
# temp: 2.0 alpha: 0.30 run_duration: 100000
# temp: 1.9 alpha: 0.30 run_duration: 100000
# temp: 1.8 alpha: 0.30 run_duration: 100000
# temp: 1.7 alpha: 0.40 run_duration: 100000
# temp: 1.6 alpha: 0.40 run_duration: 100000
# temp: 1.5 alpha: 0.40 run_duration: 100000
# temp: 1.4 alpha: 0.40 run_duration: 100000
# temp: 1.3 alpha: 0.50 run_duration: 100000
# temp: 1.2 alpha: 0.50 run_duration: 100000
# temp: 1.1 alpha: 0.60 run_duration: 100000
# temp: 1.0 alpha: 0.60 run_duration: 100000
# temp: 0.9 alpha: 0.70 run_duration: 100000
# temp: 0.8 alpha: 0.90 run_duration: 100000
# temp: 0.7 alpha: 1.10 run_duration: 100000
# temp: 0.6 alpha: 1.70 run_duration: 100000
# temp: 0.5 alpha: 2.90 run_duration: 100000
# temp: 0.4 alpha: 8.80 run_duration: 100000
# temp: 0.3 alpha: 327.40 run_duration: 100000
# temp: 0.2 ALPHA THRESHOLD MET
# SP: {'N': 32768, 'seed': 5, 'version': 2, 'potential': 'wca', 'phi': 1.2, 'epsilon_a': 0.0, 'temp': 2.0}
# Job already reached threshold

# %%
for delta, group in project.find_jobs({"version": 2}).groupby("delta"):

    group1, group2 = itertools.tee(group)

    temps = []
    for job in group1:
        with job:
            last_sim = sorted(glob.glob("not-equil_*.gsd"))[0]  # get lowest temp sim
            temp = utils.extract_between(last_sim, "not-equil_", ".gsd")
            temps.append(float(temp))  # add temp to list
    print(f"{delta:.1f}: {np.unique(temps)}")
    min_temp = np.min(temps)  # get min temp from sims of same delta

    # restart jobs that didn't reach the same end temperature at the same delta
    for job in group2:
        assert isinstance(job, signac.Project.Job)
        with job:
            last_sim = sorted(glob.glob("not-equil_*.gsd"))[0]
            temp = utils.extract_between(last_sim, "not-equil_", ".gsd")
            temps.append(float(temp))
            if np.isclose(float(temp), min_temp):  # if temp == min_temp, continue to next job
                print(temp, "No need to restart")
                continue
            else:
                print(temp, "Restarting")

        print("SP:", job.sp)
        sp = job.sp

        alpha_thresh = project.doc["threshold_alpha"]
        temp_step = project.doc["temp_step"]
        alpha_iters = project.doc["alpha_iters"]
        equil_steps = project.doc["equil_steps"]

        run_duration = 100_000  # default run duration

        # restart from the last complete simulation run
        already_done = sorted(glob.glob(job.fn("equil_*.gsd")))
        state = already_done[0]
        print(f"Resuming from a checkpoint: {state.split('/')[-1]}")
        sim = hoomd.Simulation(hoomd.device.GPU(), seed=sp["seed"]+1)
        sim.create_state_from_gsd(state)

        integrator = hoomd.md.Integrator(dt=0.001)
        tree = hoomd.md.nlist.Tree(0.3)
        if sp["potential"] == "lj":
            print("Using LJ")
            mlj = pair.KA_LJ(tree)
        elif sp["potential"] == "wlj":
            print("Using WLJ")
            mlj = pair.KA_WLJ(tree, epsilon_a=sp["epsilon_a"])
        elif sp["potential"] == "wca":
            print("Using WCA")
            mlj = pair.KA_WCA(tree)
        else:
            raise ValueError(f"Unknown potential {sp['potential']}")

        temp = state.split("equil_")[-1].split(".gsd")[0]

        nvt = hoomd.md.methods.NVT(hoomd.filter.All(), float(temp) - temp_step, 0.1)
        integrator.forces = [mlj]
        integrator.methods = [nvt]

        sim.operations.integrator = integrator

        temp_gsd = temp.replace(".", "_")
        
        with job.data:
            max_alpha_steps = roundup(int(np.max(job.data[f"{temp_gsd}/alphas"][:])*1000))
        if max_alpha_steps > run_duration:
            run_duration = max_alpha_steps

        # implement approximate greater than
        while nvt.kT(sim.timestep) - min_temp > 1e-5:

            print(f"temp: {nvt.kT(sim.timestep):.1f}", end="")

            sim.run(equil_steps)

            action = VerifyEquilibrium()
            custom_action = hoomd.update.CustomUpdater(hoomd.trigger.Periodic(run_duration//1_000), action)
            sim.operations.updaters.clear()
            sim.operations.updaters.append(custom_action)

            while len(action.alphas) < alpha_iters:
                sim.run(run_duration)
                
            cur_temp = nvt.kT(sim.timestep)
            job.data[f"rs-{cur_temp:.1f}/tsteps".replace(".", "_")] = np.array(action.tsteps)
            job.data[f"rs-{cur_temp:.1f}/msds".replace(".", "_")] = np.array(action.msds)
            job.data[f"rs-{cur_temp:.1f}/sisfs".replace(".", "_")] = np.array(action.sisfs)
            job.data[f"rs-{cur_temp:.1f}/alphas".replace(".", "_")] = np.array(action.alphas)
            job.data[f"rs-{cur_temp:.1f}/Ds".replace(".", "_")] = np.array(action.Ds)

            print(f" alpha: {np.max(action.alphas):.2f} run_duration: {run_duration}")
            max_alpha_steps = roundup(int(np.max(action.alphas)*1000))
            if max_alpha_steps > run_duration:
                run_duration = max_alpha_steps
            hoomd.write.GSD.write(sim.state, job.fn(f"rs-equil_{cur_temp:.1f}.gsd"))

            nvt.kT = cur_temp - temp_step

        del sim

# %%
# aggregate job data

for job in project.find_jobs({"version": 2}):

    if job.sp["seed"] > 2:
        continue

    print(job.sp)

    plt.figure()

    with job:
        sims = glob.glob("rs-equil_*.gsd") + sorted(glob.glob("equil_*.gsd"))
        print(sims[0])

        for sim in sims:
            temp = utils.extract_between(sim, "equil_", ".gsd")
            _temp = temp.replace(".", "_")
            # print(temp)
            if "rs" in sim:
                pre = "rs-"
            else:
                pre = ""
            with job.data:
                time = list(job.data[f"{pre}{_temp}/tsteps"][:])
                for i in range(1, len(time)):
                    if i < len(time) and time[i] < time[i-1]:
                        del time[i-1]
                data = job.data[f"{pre}{_temp}/sisfs"][:]
                plt.plot(time[:len(data)], data, ".")
            # break
        
    # plt.yscale('log')
    plt.xscale('log')
# Out:
# {'N': 32768, 'seed': 2, 'version': 2, 'potential': 'lj', 'phi': 1.0, 'temp': 2.0}
# equil_0.4.gsd
# {'N': 32768, 'seed': 0, 'version': 2, 'potential': 'lj', 'phi': 1.3, 'temp': 3.0}
# equil_0.7.gsd
# {'N': 32768, 'seed': 1, 'version': 2, 'potential': 'wlj', 'phi': 1.2, 'epsilon_a': 0.33, 'temp': 2.0}
# equil_0.4.gsd
# {'N': 32768, 'seed': 2, 'version': 2, 'potential': 'wca', 'phi': 1.2, 'epsilon_a': 0.0, 'temp': 2.0}
# equil_0.3.gsd
# {'N': 32768, 'seed': 1, 'version': 2, 'potential': 'lj', 'phi': 1.1, 'temp': 2.0}
# equil_0.3.gsd
# {'N': 32768, 'seed': 0, 'version': 2, 'potential': 'wlj', 'phi': 1.2, 'epsilon_a': 0.66, 'temp': 2.0}
# equil_0.4.gsd
